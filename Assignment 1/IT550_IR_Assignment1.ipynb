# %% [markdown]
# # IT550 - Information Retrieval
# ## Assignment 1

# %% [markdown]
# ## Importing necessary libraries:
# Firstly we will import all the necessary libraries required for this assignment.

# %%
# Setup
import nltk
nltk.download('stopwords')
nltk.download('wordnet')

import os
import re
from bs4 import BeautifulSoup
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ## Extracting contents of `<TEXT>` tag from all documents:
# We use BeautifulSoup library to extract to parse the utf8 format files contained in the *mini_dataset* folder and extract the contents in the `<TEXT>` tags.

# %%
path = 'mini_dataset'
files = os.listdir(path)
textList = []

for file in files:
  with open(os.path.join(path, file), encoding='utf8') as data:
      soup = BeautifulSoup(data, features='html.parser')

      # There will be only one pair of <TEXT> tag per file
      textTag = soup.find('text')
      
      # Extracting the contents and appending it to the list
      textList.append(textTag.text)

text = ''.join(textList)
print(text)
# Out:
# The Telegraph - Calcutta : Business
#
#  RBI breather for urban co-op banks
#
#  OUR SPECIAL CORRESPONDENT
#
#  Mumbai, Sept. 4: The Reserve Bank has relaxed loan impairment norms for urban cooperative banks. The 90-day norm relating to asset classification and provisioning will now be applicable to gold loans and small loans up to Rs 1 lakh only from the financial year ending March 31, 2007.
#
#  Till then these loans would be governed by the 180-day impairment norm.
#
#  Earlier, the central bank had advised UCBs to apply the 90-day norm from the financial year ending March 31, 2005.
#
#  The decision was based on the representations by UCBs, a Reserve Bank release said here today.
#
#  RBI governor Y. V. Reddy had held meeting with federations of co-operative banks on September 2 where UCBs sought relaxation in these norms.
#
#  In the meeting, specific suggestions were placed. These included a proposal to modify prudential regulations, including deferring the application of 90-day norm, a plan to exclude gold loans and loans below Rs 1 lakh from these norms, and to rationalise procedures governing maintenance of cash reserve ratio (CRR).
#
#  The representatives also requested that the forthcoming Basel II norms are applied in a modified form to suit their localised nature.
#
#
#
#
#
#
#
# The Telegraph - Calcutta : Business
#
#  New LIC pension plans
#
#  A STAFF REPORTER
#
#  Calcutta, Sept. 3: Life Insurance Corporation of India (LIC) plans to unveil three new products, including a unit-linked pension plan.
#
#  We have sought approval from the Insurance Regulatory and Development Authority of India (IRDA) for the approval of these three policies and will launch them soon after we receive it, said LIC zonal manager D. K. Mehrotra.
#
#  Apart from the unit-linked pension plan, the schemes would include a childrens plan and another similar to Jeevan Shree for high net-worth individuals.
#
#  Mehrotra acknowledged that the response to LICs existing pension schemes was not very encouraging. This is because of lack of awareness among employees in rural and the unorganised sector, said Mehrotra.
#
#  However, the company is planning to increase awareness among these sections of people through a number of programmes to be addressed by agents and marketing people, Mehrotra added.
#
#  Till August 14, the corporation had sold a total of 22,212 pension policies with a premium income of Rs 40 crore.
#
#  In the eastern zone, LIC had sold 4600 policies in the period between April and August 14, 2004-05, with a total premium income of Rs 6.15 crore.
#
#  During the financial year 2003-04, LIC had sold a total of 3.26 lakh pension policies with a premium income of Rs 468 crore in which the share of the eastern zone was 63,233 policies and Rs 86.40 crore in premium income.
#
#  Mehrotra said that the corporation would give special emphasis on increasing distribution channels to maintain its market share and also increase the popularity of pension schemes.
#
#  LIC markets its products through 3624 outlets of banks namely Uco Bank, Corporation Bank, Allahabad Bank, West Bengal State Co-operative Bank and have 135 licensed corporate agents who market the products through 163 outlets.
#
#  As on August 15, 2004, the eastern zone had earned premium income of Rs 410.14 crore by selling 14.05 lakh policies recording a growth of 38.82 per cent and 11.22 per cent in premium and policies respectively.
#
#  Bima Plus fetched premium of Rs 51.81 crore and seven other important new plans earned premium of Rs 64.86 crore
#
#
#
#
#
#
#
# The Telegraph - Calcutta : Business
#
#  Advisers to help WBIDC sell bad assets
#
#  SUTANUKA GHOSAL
#
#  Calcutta, Sept. 6: West Bengal Industrial Development Corporation (WBIDC) will appoint advisers to help it dispose of assets under liquidation.
#
#  The decision was taken at the corporations board meeting held last month. There are 41 such assets under liquidation and WBIDC wants to generate revenues from them.
#
#  The corporation will soon float a tender inviting bids from advisers, who will be paid on a commission basis.
#
#  There are huge assets of non-performing companies under liquidation. WBIDC has exposure in these companies. We want to unlock these idle assets and enhance revenue flow. The advisers will help us in selling these assets. The corporation will pay them good commissions, said a senior WBIDC official.
#
#  WBIDC has consciously decided to increase its standard assets in order to reduce the net non-performing asset and net asset ratio.
#
#  The corporation is planning to increase its exposure in the forthcoming projects. In the last couple of years, WBIDC had not invested heavily, the last major being Rs 12 crore in Ramrupai Steel.
#
#  Sources said the corporation may increase its exposure to Rs 40 crore in certain projects. At present, there are three steel and a cement project on WBIDCs platter.
#
#  However, the investment will all be in the form of loans. WBIDC will not invest in equity in a big way. Unless it is a very big project, WBIDC will not pick up equity. We will buy 11 per cent of Kulpi Port, which is being developed by the Bengal government, P amp; and Bengal Port, sources added.
#
#  The corporation may also buy a stake in Tatas coke oven project, which is slated to come up in Haldia.
#
#  In 2003-04, WBIDC had disbursed Rs 80 crore as loans. This year the target is Rs 100 crore.
#
#  The corporation is also trying to cut its bad assets. In 2003-04, WBIDC had trimmed its bad or non-performing assets (NPAs) by Rs 57 crore. This year the target is Rs 60 crore.
#
#  WBIDC has decided to raise money against its own receivables as part of the securitisation exercise.
#
#  ICICI Bank has agreed to provide Rs 25 crore as loan against receivables at a coupon rate of 6.95 per cent. The corporation will lend this money at a higher interest of 9.5 per cent thereby augmenting revenue for it.
#
#  State Bank of India as well as UTI Bank is keen to provide loans against receivables at an interest of 6.5 per cent.
#
#  IDBI is also keen to provide us loans at a much lower interest of 5.6 per cent. We are in talks with them, sources added.
#
#
#
#
#
#
#
# The Telegraph - Calcutta : Business
#
#  All eyes on Greenspan this week
#
#  Greenspan: In focus
#
#  London, Sept. 6 (Reuters): Federal Reserve chairman Alan Greenspans testimony on Capitol Hill midweek will be the main draw for global financial markets this week in the absence of significant data either side of the Atlantic, analysts said.
#
#  Ruthlessly put, Green- spans testimony is the only real factor that matters next week for global foreign exchange and debt markets, said Don Smith, economist at ICAP in London.
#
#  Greenspan will speak before the House of Representatives budget committee next Wednesday.
#
#  The US August non-farm payrolls report on Friday preserved the prospect of a rising Federal funds rate and analysts said it would lend support to the central bankers outlook for the worlds biggest economy.
#
#  Although employers added only 144,000 to payrolls in August, just below a median forecast of 150,000, there were upward revisions to June and July data and debt markets dived after the figures.
#
#  The non-farm payrolls dont change anything but they do provide Greenspan with more ammunition to say the economy is rebounding. It will leave scope for further tightening of rates, said Marc Ostwald, bond broker at Monument Securities in London.
#
#  US rates were last hiked by 25 basis points to 1.50 per cent on August 10. Before mid-year, they had nestled at 1 per cent for a year and were at their lowest since the mid-1950s.
#
#  Greenspan will say that tightening is necessary to remove the unnecessary accommodation given to the market before which has resulted in negative real interest rates, he added.
#
#  Since his testimony on July 20, when he noted payrolls had averaged 200,000 per month over the past six months, the average reading slowed to 106,000 in the three months to July, said a research note on Friday from HSBC Bank.
#
#  But Greenspan is likely to blame recent disappointment on the high oil price. And the recent pullback in energy prices could give him breathing room...to remain growth bullish, the note added.
#
#
#
#
#
#
#
# The Telegraph - Calcutta : Business
#
#  RBI fuels rally in bank stocks
#
#  OUR SPECIAL CORRESPONDENT
#
#  Mumbai, Sept. 3: Bank shares rallied on the stock exchanges today after the Reserve Bank of India relaxed the limits on banks bond investments yesterday. The RBI move is expected to have a positive impact on the balance-sheet of public sector banks as it would cushion them against falling government security prices.
#
#  The RBI has allowed banks to exceed the 25 per cent limit on their investments under the held-to-maturity (HTM) category provided the excess comprises only statutory liquidity ratio (SLR) securities.
#
#  The central bank also stipulated that the total SLR securities held in the HTM category should not be more than 25 per cent of their demand and time liabilities (DTL) as on the last Friday of the second preceding fortnight.
#
#  According to analysts, the RBI move will protect the balance-sheets of nationalised banks from the impact of falling government security prices. Nationalised banks are heavy investors in government securities and their investments exceed the minimum level of 25 per cent of their deposits.
#
#  Presently there are three categories under which banks can hold securities. These include HTM, available-for-sale and held-for-trading categories.
#
#  The RBI regulations stipulate that banks must mark to market their holdings in the available-for-sale and held-for-trading categories.
#
#  Market circles said bank stocks, which have been under pressure in the recent past on concerns over the impact of a likely rise in interest rates, witnessed brisk buying with investors chasing nationalised banks.
#
#  At the BSE, State Bank of India (SBI) was the most actively traded counter with the highest turnover of Rs 116.57 crore. SBI scrip firmed up by Rs 10.15 to Rs 462.15. Bank of Baroda also gained Rs 11 to finish at Rs 174.80. Corporation Bank shares were up by Rs 8 to end at Rs 259.90 and Canara Bank gained by Rs 3 to finish at Rs 141.40.
#
#  The BSE Bankex was one of the leading indices in the exchange as it gained by around 33 points. After opening at 2533.78, it shot to a days high of 2574 before closing at 2570.41.
#
#  The RBIs decision to raise the investment limits has come at a time when most of the banks have witnessed their trading gains evaporate in the first quarter of the current fiscal due to sustained drop in prices of government securities.
#
#  Treasury circles feel that the central bank is preparing the banking sector for an interest rate hike in the months to come. So far the RBI has desisted from raising key rates and the benchmark bank rate is still at a three decade low.

# %% [markdown]
# ## Removing punctuation and numerical values from the text:
# Here we remove the punctuation and numerical values using the `re.sub()` function from the re library.

# %%
cleanedText = re.sub(r'[^a-zA-Z\s]', '', text)
cleanedText = "".join(filter(lambda x: not x.isdigit(), cleanedText))

print(cleanedText)
# Out:
# The Telegraph  Calcutta  Business
#
#  RBI breather for urban coop banks
#
#  OUR SPECIAL CORRESPONDENT
#
#  Mumbai Sept  The Reserve Bank has relaxed loan impairment norms for urban cooperative banks The day norm relating to asset classification and provisioning will now be applicable to gold loans and small loans up to Rs  lakh only from the financial year ending March
#
#  Till then these loans would be governed by the day impairment norm
#
#  Earlier the central bank had advised UCBs to apply the day norm from the financial year ending March
#
#  The decision was based on the representations by UCBs a Reserve Bank release said here today
#
#  RBI governor Y V Reddy had held meeting with federations of cooperative banks on September  where UCBs sought relaxation in these norms
#
#  In the meeting specific suggestions were placed These included a proposal to modify prudential regulations including deferring the application of day norm a plan to exclude gold loans and loans below Rs  lakh from these norms and to rationalise procedures governing maintenance of cash reserve ratio CRR
#
#  The representatives also requested that the forthcoming Basel II norms are applied in a modified form to suit their localised nature
#
#
#
#
#
#
#
# The Telegraph  Calcutta  Business
#
#  New LIC pension plans
#
#  A STAFF REPORTER
#
#  Calcutta Sept  Life Insurance Corporation of India LIC plans to unveil three new products including a unitlinked pension plan
#
#  We have sought approval from the Insurance Regulatory and Development Authority of India IRDA for the approval of these three policies and will launch them soon after we receive it said LIC zonal manager D K Mehrotra
#
#  Apart from the unitlinked pension plan the schemes would include a childrens plan and another similar to Jeevan Shree for high networth individuals
#
#  Mehrotra acknowledged that the response to LICs existing pension schemes was not very encouraging This is because of lack of awareness among employees in rural and the unorganised sector said Mehrotra
#
#  However the company is planning to increase awareness among these sections of people through a number of programmes to be addressed by agents and marketing people Mehrotra added
#
#  Till August  the corporation had sold a total of  pension policies with a premium income of Rs  crore
#
#  In the eastern zone LIC had sold  policies in the period between April and August   with a total premium income of Rs  crore
#
#  During the financial year  LIC had sold a total of  lakh pension policies with a premium income of Rs  crore in which the share of the eastern zone was  policies and Rs  crore in premium income
#
#  Mehrotra said that the corporation would give special emphasis on increasing distribution channels to maintain its market share and also increase the popularity of pension schemes
#
#  LIC markets its products through  outlets of banks namely Uco Bank Corporation Bank Allahabad Bank West Bengal State Cooperative Bank and have  licensed corporate agents who market the products through  outlets
#
#  As on August   the eastern zone had earned premium income of Rs  crore by selling  lakh policies recording a growth of  per cent and  per cent in premium and policies respectively
#
#  Bima Plus fetched premium of Rs  crore and seven other important new plans earned premium of Rs  crore
#
#
#
#
#
#
#
# The Telegraph  Calcutta  Business
#
#  Advisers to help WBIDC sell bad assets
#
#  SUTANUKA GHOSAL
#
#  Calcutta Sept  West Bengal Industrial Development Corporation WBIDC will appoint advisers to help it dispose of assets under liquidation
#
#  The decision was taken at the corporations board meeting held last month There are  such assets under liquidation and WBIDC wants to generate revenues from them
#
#  The corporation will soon float a tender inviting bids from advisers who will be paid on a commission basis
#
#  There are huge assets of nonperforming companies under liquidation WBIDC has exposure in these companies We want to unlock these idle assets and enhance revenue flow The advisers will help us in selling these assets The corporation will pay them good commissions said a senior WBIDC official
#
#  WBIDC has consciously decided to increase its standard assets in order to reduce the net nonperforming asset and net asset ratio
#
#  The corporation is planning to increase its exposure in the forthcoming projects In the last couple of years WBIDC had not invested heavily the last major being Rs  crore in Ramrupai Steel
#
#  Sources said the corporation may increase its exposure to Rs  crore in certain projects At present there are three steel and a cement project on WBIDCs platter
#
#  However the investment will all be in the form of loans WBIDC will not invest in equity in a big way Unless it is a very big project WBIDC will not pick up equity We will buy  per cent of Kulpi Port which is being developed by the Bengal government P amp and Bengal Port sources added
#
#  The corporation may also buy a stake in Tatas coke oven project which is slated to come up in Haldia
#
#  In  WBIDC had disbursed Rs  crore as loans This year the target is Rs  crore
#
#  The corporation is also trying to cut its bad assets In  WBIDC had trimmed its bad or nonperforming assets NPAs by Rs  crore This year the target is Rs  crore
#
#  WBIDC has decided to raise money against its own receivables as part of the securitisation exercise
#
#  ICICI Bank has agreed to provide Rs  crore as loan against receivables at a coupon rate of  per cent The corporation will lend this money at a higher interest of  per cent thereby augmenting revenue for it
#
#  State Bank of India as well as UTI Bank is keen to provide loans against receivables at an interest of  per cent
#
#  IDBI is also keen to provide us loans at a much lower interest of  per cent We are in talks with them sources added
#
#
#
#
#
#
#
# The Telegraph  Calcutta  Business
#
#  All eyes on Greenspan this week
#
#  Greenspan In focus
#
#  London Sept  Reuters Federal Reserve chairman Alan Greenspans testimony on Capitol Hill midweek will be the main draw for global financial markets this week in the absence of significant data either side of the Atlantic analysts said
#
#  Ruthlessly put Green spans testimony is the only real factor that matters next week for global foreign exchange and debt markets said Don Smith economist at ICAP in London
#
#  Greenspan will speak before the House of Representatives budget committee next Wednesday
#
#  The US August nonfarm payrolls report on Friday preserved the prospect of a rising Federal funds rate and analysts said it would lend support to the central bankers outlook for the worlds biggest economy
#
#  Although employers added only  to payrolls in August just below a median forecast of  there were upward revisions to June and July data and debt markets dived after the figures
#
#  The nonfarm payrolls dont change anything but they do provide Greenspan with more ammunition to say the economy is rebounding It will leave scope for further tightening of rates said Marc Ostwald bond broker at Monument Securities in London
#
#  US rates were last hiked by  basis points to  per cent on August  Before midyear they had nestled at  per cent for a year and were at their lowest since the mids
#
#  Greenspan will say that tightening is necessary to remove the unnecessary accommodation given to the market before which has resulted in negative real interest rates he added
#
#  Since his testimony on July  when he noted payrolls had averaged  per month over the past six months the average reading slowed to  in the three months to July said a research note on Friday from HSBC Bank
#
#  But Greenspan is likely to blame recent disappointment on the high oil price And the recent pullback in energy prices could give him breathing roomto remain growth bullish the note added
#
#
#
#
#
#
#
# The Telegraph  Calcutta  Business
#
#  RBI fuels rally in bank stocks
#
#  OUR SPECIAL CORRESPONDENT
#
#  Mumbai Sept  Bank shares rallied on the stock exchanges today after the Reserve Bank of India relaxed the limits on banks bond investments yesterday The RBI move is expected to have a positive impact on the balancesheet of public sector banks as it would cushion them against falling government security prices
#
#  The RBI has allowed banks to exceed the  per cent limit on their investments under the heldtomaturity HTM category provided the excess comprises only statutory liquidity ratio SLR securities
#
#  The central bank also stipulated that the total SLR securities held in the HTM category should not be more than  per cent of their demand and time liabilities DTL as on the last Friday of the second preceding fortnight
#
#  According to analysts the RBI move will protect the balancesheets of nationalised banks from the impact of falling government security prices Nationalised banks are heavy investors in government securities and their investments exceed the minimum level of  per cent of their deposits
#
#  Presently there are three categories under which banks can hold securities These include HTM availableforsale and heldfortrading categories
#
#  The RBI regulations stipulate that banks must mark to market their holdings in the availableforsale and heldfortrading categories
#
#  Market circles said bank stocks which have been under pressure in the recent past on concerns over the impact of a likely rise in interest rates witnessed brisk buying with investors chasing nationalised banks
#
#  At the BSE State Bank of India SBI was the most actively traded counter with the highest turnover of Rs  crore SBI scrip firmed up by Rs  to Rs  Bank of Baroda also gained Rs  to finish at Rs  Corporation Bank shares were up by Rs  to end at Rs  and Canara Bank gained by Rs  to finish at Rs
#
#  The BSE Bankex was one of the leading indices in the exchange as it gained by around  points After opening at  it shot to a days high of  before closing at
#
#  The RBIs decision to raise the investment limits has come at a time when most of the banks have witnessed their trading gains evaporate in the first quarter of the current fiscal due to sustained drop in prices of government securities
#
#  Treasury circles feel that the central bank is preparing the banking sector for an interest rate hike in the months to come So far the RBI has desisted from raising key rates and the benchmark bank rate is still at a three decade low

# %% [markdown]
# ## Performing tokenization the text:
# Here we show differences between two tokenization methods.<br>
# One way to tokenize is by using `split()` function.<br>
# Another way we can tokenize is using `nltk` library's `nltk.word_tokenize()` function.
# <br>
# <br>
# As we can see both ways gives us the same results.<br>
# It is because we have removed numerical values and punctuations from the text that they are tokenized the same by both methods. If the punctuations and numerical values were to be kept then `nltk.word_tokenize()` would have returned more accurate tokens while `str.split()` would split as per the whitespace characters only which not always return correct word tokens.

# %%
tokenizeSplit = cleanedText.split()
tokenizeNLTK = nltk.word_tokenize(cleanedText)

# print(len(tokenizeSplit), len(tokenizeNLTK))
print("Tokenizing by two methods:")
print("By Split".ljust(15), "<----------->", "By NLTK".rjust(15), end="\n\n")

for tbs, tbn in zip(tokenizeSplit, tokenizeNLTK):
  print(tbs.ljust(15), "<----------->", tbn.rjust(15))
# Out:
# Tokenizing by two methods:
# By Split        <----------->         By NLTK
#
# The             <----------->             The
# Telegraph       <----------->       Telegraph
# Calcutta        <----------->        Calcutta
# Business        <----------->        Business
# RBI             <----------->             RBI
# breather        <----------->        breather
# for             <----------->             for
# urban           <----------->           urban
# coop            <----------->            coop
# banks           <----------->           banks
# OUR             <----------->             OUR
# SPECIAL         <----------->         SPECIAL
# CORRESPONDENT   <----------->   CORRESPONDENT
# Mumbai          <----------->          Mumbai
# Sept            <----------->            Sept
# The             <----------->             The
# Reserve         <----------->         Reserve
# Bank            <----------->            Bank
# has             <----------->             has
# relaxed         <----------->         relaxed
# loan            <----------->            loan
# impairment      <----------->      impairment
# norms           <----------->           norms
# for             <----------->             for
# urban           <----------->           urban
# cooperative     <----------->     cooperative
# banks           <----------->           banks
# The             <----------->             The
# day             <----------->             day
# norm            <----------->            norm
# relating        <----------->        relating
# to              <----------->              to
# asset           <----------->           asset
# classification  <----------->  classification
# and             <----------->             and
# provisioning    <----------->    provisioning
# will            <----------->            will
# now             <----------->             now
# be              <----------->              be
# applicable      <----------->      applicable
# to              <----------->              to
# gold            <----------->            gold
# loans           <----------->           loans
# and             <----------->             and
# small           <----------->           small
# loans           <----------->           loans
# up              <----------->              up
# to              <----------->              to
# Rs              <----------->              Rs
# lakh            <----------->            lakh
# only            <----------->            only
# from            <----------->            from
# the             <----------->             the
# financial       <----------->       financial
# year            <----------->            year
# ending          <----------->          ending
# March           <----------->           March
# Till            <----------->            Till
# then            <----------->            then
# these           <----------->           these
# loans           <----------->           loans
# would           <----------->           would
# be              <----------->              be
# governed        <----------->        governed
# by              <----------->              by
# the             <----------->             the
# day             <----------->             day
# impairment      <----------->      impairment
# norm            <----------->            norm
# Earlier         <----------->         Earlier
# the             <----------->             the
# central         <----------->         central
# bank            <----------->            bank
# had             <----------->             had
# advised         <----------->         advised
# UCBs            <----------->            UCBs
# to              <----------->              to
# apply           <----------->           apply
# the             <----------->             the
# day             <----------->             day
# norm            <----------->            norm
# from            <----------->            from
# the             <----------->             the
# financial       <----------->       financial
# year            <----------->            year
# ending          <----------->          ending
# March           <----------->           March
# The             <----------->             The
# decision        <----------->        decision
# was             <----------->             was
# based           <----------->           based
# on              <----------->              on
# the             <----------->             the
# representations <-----------> representations
# by              <----------->              by
# UCBs            <----------->            UCBs
# a               <----------->               a
# Reserve         <----------->         Reserve
# Bank            <----------->            Bank
# release         <----------->         release
# said            <----------->            said
# here            <----------->            here
# today           <----------->           today
# RBI             <----------->             RBI
# governor        <----------->        governor
# Y               <----------->               Y
# V               <----------->               V
# Reddy           <----------->           Reddy
# had             <----------->             had
# held            <----------->            held
# meeting         <----------->         meeting
# with            <----------->            with
# federations     <----------->     federations
# of              <----------->              of
# cooperative     <----------->     cooperative
# banks           <----------->           banks
# on              <----------->              on
# September       <----------->       September
# where           <----------->           where
# UCBs            <----------->            UCBs
# sought          <----------->          sought
# relaxation      <----------->      relaxation
# in              <----------->              in
# these           <----------->           these
# norms           <----------->           norms
# In              <----------->              In
# the             <----------->             the
# meeting         <----------->         meeting
# specific        <----------->        specific
# suggestions     <----------->     suggestions
# were            <----------->            were
# placed          <----------->          placed
# These           <----------->           These
# included        <----------->        included
# a               <----------->               a
# proposal        <----------->        proposal
# to              <----------->              to
# modify          <----------->          modify
# prudential      <----------->      prudential
# regulations     <----------->     regulations
# including       <----------->       including
# deferring       <----------->       deferring
# the             <----------->             the
# application     <----------->     application
# of              <----------->              of
# day             <----------->             day
# norm            <----------->            norm
# a               <----------->               a
# plan            <----------->            plan
# to              <----------->              to
# exclude         <----------->         exclude
# gold            <----------->            gold
# loans           <----------->           loans
# and             <----------->             and
# loans           <----------->           loans
# below           <----------->           below
# Rs              <----------->              Rs
# lakh            <----------->            lakh
# from            <----------->            from
# these           <----------->           these
# norms           <----------->           norms
# and             <----------->             and
# to              <----------->              to
# rationalise     <----------->     rationalise
# procedures      <----------->      procedures
# governing       <----------->       governing
# maintenance     <----------->     maintenance
# of              <----------->              of
# cash            <----------->            cash
# reserve         <----------->         reserve
# ratio           <----------->           ratio
# CRR             <----------->             CRR
# The             <----------->             The
# representatives <-----------> representatives
# also            <----------->            also
# requested       <----------->       requested
# that            <----------->            that
# the             <----------->             the
# forthcoming     <----------->     forthcoming
# Basel           <----------->           Basel
# II              <----------->              II
# norms           <----------->           norms
# are             <----------->             are
# applied         <----------->         applied
# in              <----------->              in
# a               <----------->               a
# modified        <----------->        modified
# form            <----------->            form
# to              <----------->              to
# suit            <----------->            suit
# their           <----------->           their
# localised       <----------->       localised
# nature          <----------->          nature
# The             <----------->             The
# Telegraph       <----------->       Telegraph
# Calcutta        <----------->        Calcutta
# Business        <----------->        Business
# New             <----------->             New
# LIC             <----------->             LIC
# pension         <----------->         pension
# plans           <----------->           plans
# A               <----------->               A
# STAFF           <----------->           STAFF
# REPORTER        <----------->        REPORTER
# Calcutta        <----------->        Calcutta
# Sept            <----------->            Sept
# Life            <----------->            Life
# Insurance       <----------->       Insurance
# Corporation     <----------->     Corporation
# of              <----------->              of
# India           <----------->           India
# LIC             <----------->             LIC
# plans           <----------->           plans
# to              <----------->              to
# unveil          <----------->          unveil
# three           <----------->           three
# new             <----------->             new
# products        <----------->        products
# including       <----------->       including
# a               <----------->               a
# unitlinked      <----------->      unitlinked
# pension         <----------->         pension
# plan            <----------->            plan
# We              <----------->              We
# have            <----------->            have
# sought          <----------->          sought
# approval        <----------->        approval
# from            <----------->            from
# the             <----------->             the
# Insurance       <----------->       Insurance
# Regulatory      <----------->      Regulatory
# and             <----------->             and
# Development     <----------->     Development
# Authority       <----------->       Authority
# of              <----------->              of
# India           <----------->           India
# IRDA            <----------->            IRDA
# for             <----------->             for
# the             <----------->             the
# approval        <----------->        approval
# of              <----------->              of
# these           <----------->           these
# three           <----------->           three
# policies        <----------->        policies
# and             <----------->             and
# will            <----------->            will
# launch          <----------->          launch
# them            <----------->            them
# soon            <----------->            soon
# after           <----------->           after
# we              <----------->              we
# receive         <----------->         receive
# it              <----------->              it
# said            <----------->            said
# LIC             <----------->             LIC
# zonal           <----------->           zonal
# manager         <----------->         manager
# D               <----------->               D
# K               <----------->               K
# Mehrotra        <----------->        Mehrotra
# Apart           <----------->           Apart
# from            <----------->            from
# the             <----------->             the
# unitlinked      <----------->      unitlinked
# pension         <----------->         pension
# plan            <----------->            plan
# the             <----------->             the
# schemes         <----------->         schemes
# would           <----------->           would
# include         <----------->         include
# a               <----------->               a
# childrens       <----------->       childrens
# plan            <----------->            plan
# and             <----------->             and
# another         <----------->         another
# similar         <----------->         similar
# to              <----------->              to
# Jeevan          <----------->          Jeevan
# Shree           <----------->           Shree
# for             <----------->             for
# high            <----------->            high
# networth        <----------->        networth
# individuals     <----------->     individuals
# Mehrotra        <----------->        Mehrotra
# acknowledged    <----------->    acknowledged
# that            <----------->            that
# the             <----------->             the
# response        <----------->        response
# to              <----------->              to
# LICs            <----------->            LICs
# existing        <----------->        existing
# pension         <----------->         pension
# schemes         <----------->         schemes
# was             <----------->             was
# not             <----------->             not
# very            <----------->            very
# encouraging     <----------->     encouraging
# This            <----------->            This
# is              <----------->              is
# because         <----------->         because
# of              <----------->              of
# lack            <----------->            lack
# of              <----------->              of
# awareness       <----------->       awareness
# among           <----------->           among
# employees       <----------->       employees
# in              <----------->              in
# rural           <----------->           rural
# and             <----------->             and
# the             <----------->             the
# unorganised     <----------->     unorganised
# sector          <----------->          sector
# said            <----------->            said
# Mehrotra        <----------->        Mehrotra
# However         <----------->         However
# the             <----------->             the
# company         <----------->         company
# is              <----------->              is
# planning        <----------->        planning
# to              <----------->              to
# increase        <----------->        increase
# awareness       <----------->       awareness
# among           <----------->           among
# these           <----------->           these
# sections        <----------->        sections
# of              <----------->              of
# people          <----------->          people
# through         <----------->         through
# a               <----------->               a
# number          <----------->          number
# of              <----------->              of
# programmes      <----------->      programmes
# to              <----------->              to
# be              <----------->              be
# addressed       <----------->       addressed
# by              <----------->              by
# agents          <----------->          agents
# and             <----------->             and
# marketing       <----------->       marketing
# people          <----------->          people
# Mehrotra        <----------->        Mehrotra
# added           <----------->           added
# Till            <----------->            Till
# August          <----------->          August
# the             <----------->             the
# corporation     <----------->     corporation
# had             <----------->             had
# sold            <----------->            sold
# a               <----------->               a
# total           <----------->           total
# of              <----------->              of
# pension         <----------->         pension
# policies        <----------->        policies
# with            <----------->            with
# a               <----------->               a
# premium         <----------->         premium
# income          <----------->          income
# of              <----------->              of
# Rs              <----------->              Rs
# crore           <----------->           crore
# In              <----------->              In
# the             <----------->             the
# eastern         <----------->         eastern
# zone            <----------->            zone
# LIC             <----------->             LIC
# had             <----------->             had
# sold            <----------->            sold
# policies        <----------->        policies
# in              <----------->              in
# the             <----------->             the
# period          <----------->          period
# between         <----------->         between
# April           <----------->           April
# and             <----------->             and
# August          <----------->          August
# with            <----------->            with
# a               <----------->               a
# total           <----------->           total
# premium         <----------->         premium
# income          <----------->          income
# of              <----------->              of
# Rs              <----------->              Rs
# crore           <----------->           crore
# During          <----------->          During
# the             <----------->             the
# financial       <----------->       financial
# year            <----------->            year
# LIC             <----------->             LIC
# had             <----------->             had
# sold            <----------->            sold
# a               <----------->               a
# total           <----------->           total
# of              <----------->              of
# lakh            <----------->            lakh
# pension         <----------->         pension
# policies        <----------->        policies
# with            <----------->            with
# a               <----------->               a
# premium         <----------->         premium
# income          <----------->          income
# of              <----------->              of
# Rs              <----------->              Rs
# crore           <----------->           crore
# in              <----------->              in
# which           <----------->           which
# the             <----------->             the
# share           <----------->           share
# of              <----------->              of
# the             <----------->             the
# eastern         <----------->         eastern
# zone            <----------->            zone
# was             <----------->             was
# policies        <----------->        policies
# and             <----------->             and
# Rs              <----------->              Rs
# crore           <----------->           crore
# in              <----------->              in
# premium         <----------->         premium
# income          <----------->          income
# Mehrotra        <----------->        Mehrotra
# said            <----------->            said
# that            <----------->            that
# the             <----------->             the
# corporation     <----------->     corporation
# would           <----------->           would
# give            <----------->            give
# special         <----------->         special
# emphasis        <----------->        emphasis
# on              <----------->              on
# increasing      <----------->      increasing
# distribution    <----------->    distribution
# channels        <----------->        channels
# to              <----------->              to
# maintain        <----------->        maintain
# its             <----------->             its
# market          <----------->          market
# share           <----------->           share
# and             <----------->             and
# also            <----------->            also
# increase        <----------->        increase
# the             <----------->             the
# popularity      <----------->      popularity
# of              <----------->              of
# pension         <----------->         pension
# schemes         <----------->         schemes
# LIC             <----------->             LIC
# markets         <----------->         markets
# its             <----------->             its
# products        <----------->        products
# through         <----------->         through
# outlets         <----------->         outlets
# of              <----------->              of
# banks           <----------->           banks
# namely          <----------->          namely
# Uco             <----------->             Uco
# Bank            <----------->            Bank
# Corporation     <----------->     Corporation
# Bank            <----------->            Bank
# Allahabad       <----------->       Allahabad
# Bank            <----------->            Bank
# West            <----------->            West
# Bengal          <----------->          Bengal
# State           <----------->           State
# Cooperative     <----------->     Cooperative
# Bank            <----------->            Bank
# and             <----------->             and
# have            <----------->            have
# licensed        <----------->        licensed
# corporate       <----------->       corporate
# agents          <----------->          agents
# who             <----------->             who
# market          <----------->          market
# the             <----------->             the
# products        <----------->        products
# through         <----------->         through
# outlets         <----------->         outlets
# As              <----------->              As
# on              <----------->              on
# August          <----------->          August
# the             <----------->             the
# eastern         <----------->         eastern
# zone            <----------->            zone
# had             <----------->             had
# earned          <----------->          earned
# premium         <----------->         premium
# income          <----------->          income
# of              <----------->              of
# Rs              <----------->              Rs
# crore           <----------->           crore
# by              <----------->              by
# selling         <----------->         selling
# lakh            <----------->            lakh
# policies        <----------->        policies
# recording       <----------->       recording
# a               <----------->               a
# growth          <----------->          growth
# of              <----------->              of
# per             <----------->             per
# cent            <----------->            cent
# and             <----------->             and
# per             <----------->             per
# cent            <----------->            cent
# in              <----------->              in
# premium         <----------->         premium
# and             <----------->             and
# policies        <----------->        policies
# respectively    <----------->    respectively
# Bima            <----------->            Bima
# Plus            <----------->            Plus
# fetched         <----------->         fetched
# premium         <----------->         premium
# of              <----------->              of
# Rs              <----------->              Rs
# crore           <----------->           crore
# and             <----------->             and
# seven           <----------->           seven
# other           <----------->           other
# important       <----------->       important
# new             <----------->             new
# plans           <----------->           plans
# earned          <----------->          earned
# premium         <----------->         premium
# of              <----------->              of
# Rs              <----------->              Rs
# crore           <----------->           crore
# The             <----------->             The
# Telegraph       <----------->       Telegraph
# Calcutta        <----------->        Calcutta
# Business        <----------->        Business
# Advisers        <----------->        Advisers
# to              <----------->              to
# help            <----------->            help
# WBIDC           <----------->           WBIDC
# sell            <----------->            sell
# bad             <----------->             bad
# assets          <----------->          assets
# SUTANUKA        <----------->        SUTANUKA
# GHOSAL          <----------->          GHOSAL
# Calcutta        <----------->        Calcutta
# Sept            <----------->            Sept
# West            <----------->            West
# Bengal          <----------->          Bengal
# Industrial      <----------->      Industrial
# Development     <----------->     Development
# Corporation     <----------->     Corporation
# WBIDC           <----------->           WBIDC
# will            <----------->            will
# appoint         <----------->         appoint
# advisers        <----------->        advisers
# to              <----------->              to
# help            <----------->            help
# it              <----------->              it
# dispose         <----------->         dispose
# of              <----------->              of
# assets          <----------->          assets
# under           <----------->           under
# liquidation     <----------->     liquidation
# The             <----------->             The
# decision        <----------->        decision
# was             <----------->             was
# taken           <----------->           taken
# at              <----------->              at
# the             <----------->             the
# corporations    <----------->    corporations
# board           <----------->           board
# meeting         <----------->         meeting
# held            <----------->            held
# last            <----------->            last
# month           <----------->           month
# There           <----------->           There
# are             <----------->             are
# such            <----------->            such
# assets          <----------->          assets
# under           <----------->           under
# liquidation     <----------->     liquidation
# and             <----------->             and
# WBIDC           <----------->           WBIDC
# wants           <----------->           wants
# to              <----------->              to
# generate        <----------->        generate
# revenues        <----------->        revenues
# from            <----------->            from
# them            <----------->            them
# The             <----------->             The
# corporation     <----------->     corporation
# will            <----------->            will
# soon            <----------->            soon
# float           <----------->           float
# a               <----------->               a
# tender          <----------->          tender
# inviting        <----------->        inviting
# bids            <----------->            bids
# from            <----------->            from
# advisers        <----------->        advisers
# who             <----------->             who
# will            <----------->            will
# be              <----------->              be
# paid            <----------->            paid
# on              <----------->              on
# a               <----------->               a
# commission      <----------->      commission
# basis           <----------->           basis
# There           <----------->           There
# are             <----------->             are
# huge            <----------->            huge
# assets          <----------->          assets
# of              <----------->              of
# nonperforming   <----------->   nonperforming
# companies       <----------->       companies
# under           <----------->           under
# liquidation     <----------->     liquidation
# WBIDC           <----------->           WBIDC
# has             <----------->             has
# exposure        <----------->        exposure
# in              <----------->              in
# these           <----------->           these
# companies       <----------->       companies
# We              <----------->              We
# want            <----------->            want
# to              <----------->              to
# unlock          <----------->          unlock
# these           <----------->           these
# idle            <----------->            idle
# assets          <----------->          assets
# and             <----------->             and
# enhance         <----------->         enhance
# revenue         <----------->         revenue
# flow            <----------->            flow
# The             <----------->             The
# advisers        <----------->        advisers
# will            <----------->            will
# help            <----------->            help
# us              <----------->              us
# in              <----------->              in
# selling         <----------->         selling
# these           <----------->           these
# assets          <----------->          assets
# The             <----------->             The
# corporation     <----------->     corporation
# will            <----------->            will
# pay             <----------->             pay
# them            <----------->            them
# good            <----------->            good
# commissions     <----------->     commissions
# said            <----------->            said
# a               <----------->               a
# senior          <----------->          senior
# WBIDC           <----------->           WBIDC
# official        <----------->        official
# WBIDC           <----------->           WBIDC
# has             <----------->             has
# consciously     <----------->     consciously
# decided         <----------->         decided
# to              <----------->              to
# increase        <----------->        increase
# its             <----------->             its
# standard        <----------->        standard
# assets          <----------->          assets
# in              <----------->              in
# order           <----------->           order
# to              <----------->              to
# reduce          <----------->          reduce
# the             <----------->             the
# net             <----------->             net
# nonperforming   <----------->   nonperforming
# asset           <----------->           asset
# and             <----------->             and
# net             <----------->             net
# asset           <----------->           asset
# ratio           <----------->           ratio
# The             <----------->             The
# corporation     <----------->     corporation
# is              <----------->              is
# planning        <----------->        planning
# to              <----------->              to
# increase        <----------->        increase
# its             <----------->             its
# exposure        <----------->        exposure
# in              <----------->              in
# the             <----------->             the
# forthcoming     <----------->     forthcoming
# projects        <----------->        projects
# In              <----------->              In
# the             <----------->             the
# last            <----------->            last
# couple          <----------->          couple
# of              <----------->              of
# years           <----------->           years
# WBIDC           <----------->           WBIDC
# had             <----------->             had
# not             <----------->             not
# invested        <----------->        invested
# heavily         <----------->         heavily
# the             <----------->             the
# last            <----------->            last
# major           <----------->           major
# being           <----------->           being
# Rs              <----------->              Rs
# crore           <----------->           crore
# in              <----------->              in
# Ramrupai        <----------->        Ramrupai
# Steel           <----------->           Steel
# Sources         <----------->         Sources
# said            <----------->            said
# the             <----------->             the
# corporation     <----------->     corporation
# may             <----------->             may
# increase        <----------->        increase
# its             <----------->             its
# exposure        <----------->        exposure
# to              <----------->              to
# Rs              <----------->              Rs
# crore           <----------->           crore
# in              <----------->              in
# certain         <----------->         certain
# projects        <----------->        projects
# At              <----------->              At
# present         <----------->         present
# there           <----------->           there
# are             <----------->             are
# three           <----------->           three
# steel           <----------->           steel
# and             <----------->             and
# a               <----------->               a
# cement          <----------->          cement
# project         <----------->         project
# on              <----------->              on
# WBIDCs          <----------->          WBIDCs
# platter         <----------->         platter
# However         <----------->         However
# the             <----------->             the
# investment      <----------->      investment
# will            <----------->            will
# all             <----------->             all
# be              <----------->              be
# in              <----------->              in
# the             <----------->             the
# form            <----------->            form
# of              <----------->              of
# loans           <----------->           loans
# WBIDC           <----------->           WBIDC
# will            <----------->            will
# not             <----------->             not
# invest          <----------->          invest
# in              <----------->              in
# equity          <----------->          equity
# in              <----------->              in
# a               <----------->               a
# big             <----------->             big
# way             <----------->             way
# Unless          <----------->          Unless
# it              <----------->              it
# is              <----------->              is
# a               <----------->               a
# very            <----------->            very
# big             <----------->             big
# project         <----------->         project
# WBIDC           <----------->           WBIDC
# will            <----------->            will
# not             <----------->             not
# pick            <----------->            pick
# up              <----------->              up
# equity          <----------->          equity
# We              <----------->              We
# will            <----------->            will
# buy             <----------->             buy
# per             <----------->             per
# cent            <----------->            cent
# of              <----------->              of
# Kulpi           <----------->           Kulpi
# Port            <----------->            Port
# which           <----------->           which
# is              <----------->              is
# being           <----------->           being
# developed       <----------->       developed
# by              <----------->              by
# the             <----------->             the
# Bengal          <----------->          Bengal
# government      <----------->      government
# P               <----------->               P
# amp             <----------->             amp
# and             <----------->             and
# Bengal          <----------->          Bengal
# Port            <----------->            Port
# sources         <----------->         sources
# added           <----------->           added
# The             <----------->             The
# corporation     <----------->     corporation
# may             <----------->             may
# also            <----------->            also
# buy             <----------->             buy
# a               <----------->               a
# stake           <----------->           stake
# in              <----------->              in
# Tatas           <----------->           Tatas
# coke            <----------->            coke
# oven            <----------->            oven
# project         <----------->         project
# which           <----------->           which
# is              <----------->              is
# slated          <----------->          slated
# to              <----------->              to
# come            <----------->            come
# up              <----------->              up
# in              <----------->              in
# Haldia          <----------->          Haldia
# In              <----------->              In
# WBIDC           <----------->           WBIDC
# had             <----------->             had
# disbursed       <----------->       disbursed
# Rs              <----------->              Rs
# crore           <----------->           crore
# as              <----------->              as
# loans           <----------->           loans
# This            <----------->            This
# year            <----------->            year
# the             <----------->             the
# target          <----------->          target
# is              <----------->              is
# Rs              <----------->              Rs
# crore           <----------->           crore
# The             <----------->             The
# corporation     <----------->     corporation
# is              <----------->              is
# also            <----------->            also
# trying          <----------->          trying
# to              <----------->              to
# cut             <----------->             cut
# its             <----------->             its
# bad             <----------->             bad
# assets          <----------->          assets
# In              <----------->              In
# WBIDC           <----------->           WBIDC
# had             <----------->             had
# trimmed         <----------->         trimmed
# its             <----------->             its
# bad             <----------->             bad
# or              <----------->              or
# nonperforming   <----------->   nonperforming
# assets          <----------->          assets
# NPAs            <----------->            NPAs
# by              <----------->              by
# Rs              <----------->              Rs
# crore           <----------->           crore
# This            <----------->            This
# year            <----------->            year
# the             <----------->             the
# target          <----------->          target
# is              <----------->              is
# Rs              <----------->              Rs
# crore           <----------->           crore
# WBIDC           <----------->           WBIDC
# has             <----------->             has
# decided         <----------->         decided
# to              <----------->              to
# raise           <----------->           raise
# money           <----------->           money
# against         <----------->         against
# its             <----------->             its
# own             <----------->             own
# receivables     <----------->     receivables
# as              <----------->              as
# part            <----------->            part
# of              <----------->              of
# the             <----------->             the
# securitisation  <----------->  securitisation
# exercise        <----------->        exercise
# ICICI           <----------->           ICICI
# Bank            <----------->            Bank
# has             <----------->             has
# agreed          <----------->          agreed
# to              <----------->              to
# provide         <----------->         provide
# Rs              <----------->              Rs
# crore           <----------->           crore
# as              <----------->              as
# loan            <----------->            loan
# against         <----------->         against
# receivables     <----------->     receivables
# at              <----------->              at
# a               <----------->               a
# coupon          <----------->          coupon
# rate            <----------->            rate
# of              <----------->              of
# per             <----------->             per
# cent            <----------->            cent
# The             <----------->             The
# corporation     <----------->     corporation
# will            <----------->            will
# lend            <----------->            lend
# this            <----------->            this
# money           <----------->           money
# at              <----------->              at
# a               <----------->               a
# higher          <----------->          higher
# interest        <----------->        interest
# of              <----------->              of
# per             <----------->             per
# cent            <----------->            cent
# thereby         <----------->         thereby
# augmenting      <----------->      augmenting
# revenue         <----------->         revenue
# for             <----------->             for
# it              <----------->              it
# State           <----------->           State
# Bank            <----------->            Bank
# of              <----------->              of
# India           <----------->           India
# as              <----------->              as
# well            <----------->            well
# as              <----------->              as
# UTI             <----------->             UTI
# Bank            <----------->            Bank
# is              <----------->              is
# keen            <----------->            keen
# to              <----------->              to
# provide         <----------->         provide
# loans           <----------->           loans
# against         <----------->         against
# receivables     <----------->     receivables
# at              <----------->              at
# an              <----------->              an
# interest        <----------->        interest
# of              <----------->              of
# per             <----------->             per
# cent            <----------->            cent
# IDBI            <----------->            IDBI
# is              <----------->              is
# also            <----------->            also
# keen            <----------->            keen
# to              <----------->              to
# provide         <----------->         provide
# us              <----------->              us
# loans           <----------->           loans
# at              <----------->              at
# a               <----------->               a
# much            <----------->            much
# lower           <----------->           lower
# interest        <----------->        interest
# of              <----------->              of
# per             <----------->             per
# cent            <----------->            cent
# We              <----------->              We
# are             <----------->             are
# in              <----------->              in
# talks           <----------->           talks
# with            <----------->            with
# them            <----------->            them
# sources         <----------->         sources
# added           <----------->           added
# The             <----------->             The
# Telegraph       <----------->       Telegraph
# Calcutta        <----------->        Calcutta
# Business        <----------->        Business
# All             <----------->             All
# eyes            <----------->            eyes
# on              <----------->              on
# Greenspan       <----------->       Greenspan
# this            <----------->            this
# week            <----------->            week
# Greenspan       <----------->       Greenspan
# In              <----------->              In
# focus           <----------->           focus
# London          <----------->          London
# Sept            <----------->            Sept
# Reuters         <----------->         Reuters
# Federal         <----------->         Federal
# Reserve         <----------->         Reserve
# chairman        <----------->        chairman
# Alan            <----------->            Alan
# Greenspans      <----------->      Greenspans
# testimony       <----------->       testimony
# on              <----------->              on
# Capitol         <----------->         Capitol
# Hill            <----------->            Hill
# midweek         <----------->         midweek
# will            <----------->            will
# be              <----------->              be
# the             <----------->             the
# main            <----------->            main
# draw            <----------->            draw
# for             <----------->             for
# global          <----------->          global
# financial       <----------->       financial
# markets         <----------->         markets
# this            <----------->            this
# week            <----------->            week
# in              <----------->              in
# the             <----------->             the
# absence         <----------->         absence
# of              <----------->              of
# significant     <----------->     significant
# data            <----------->            data
# either          <----------->          either
# side            <----------->            side
# of              <----------->              of
# the             <----------->             the
# Atlantic        <----------->        Atlantic
# analysts        <----------->        analysts
# said            <----------->            said
# Ruthlessly      <----------->      Ruthlessly
# put             <----------->             put
# Green           <----------->           Green
# spans           <----------->           spans
# testimony       <----------->       testimony
# is              <----------->              is
# the             <----------->             the
# only            <----------->            only
# real            <----------->            real
# factor          <----------->          factor
# that            <----------->            that
# matters         <----------->         matters
# next            <----------->            next
# week            <----------->            week
# for             <----------->             for
# global          <----------->          global
# foreign         <----------->         foreign
# exchange        <----------->        exchange
# and             <----------->             and
# debt            <----------->            debt
# markets         <----------->         markets
# said            <----------->            said
# Don             <----------->             Don
# Smith           <----------->           Smith
# economist       <----------->       economist
# at              <----------->              at
# ICAP            <----------->            ICAP
# in              <----------->              in
# London          <----------->          London
# Greenspan       <----------->       Greenspan
# will            <----------->            will
# speak           <----------->           speak
# before          <----------->          before
# the             <----------->             the
# House           <----------->           House
# of              <----------->              of
# Representatives <-----------> Representatives
# budget          <----------->          budget
# committee       <----------->       committee
# next            <----------->            next
# Wednesday       <----------->       Wednesday
# ...
# cent            <----------->            cent
# limit           <----------->           limit
# on              <----------->              on
# their           <----------->           their
# investments     <----------->     investments
# under           <----------->           under
# the             <----------->             the
# heldtomaturity  <----------->  heldtomaturity
# HTM             <----------->             HTM
# category        <----------->        category
# provided        <----------->        provided
# the             <----------->             the
# excess          <----------->          excess
# comprises       <----------->       comprises
# only            <----------->            only
# statutory       <----------->       statutory
# liquidity       <----------->       liquidity
# ratio           <----------->           ratio
# SLR             <----------->             SLR
# securities      <----------->      securities
# The             <----------->             The
# central         <----------->         central
# bank            <----------->            bank
# also            <----------->            also
# stipulated      <----------->      stipulated
# that            <----------->            that
# the             <----------->             the
# total           <----------->           total
# SLR             <----------->             SLR
# securities      <----------->      securities
# held            <----------->            held
# in              <----------->              in
# the             <----------->             the
# HTM             <----------->             HTM
# category        <----------->        category
# should          <----------->          should
# not             <----------->             not
# be              <----------->              be
# more            <----------->            more
# than            <----------->            than
# per             <----------->             per
# cent            <----------->            cent
# of              <----------->              of
# their           <----------->           their
# demand          <----------->          demand
# and             <----------->             and
# time            <----------->            time
# liabilities     <----------->     liabilities
# DTL             <----------->             DTL
# as              <----------->              as
# on              <----------->              on
# the             <----------->             the
# last            <----------->            last
# Friday          <----------->          Friday
# of              <----------->              of
# the             <----------->             the
# second          <----------->          second
# preceding       <----------->       preceding
# fortnight       <----------->       fortnight
# According       <----------->       According
# to              <----------->              to
# analysts        <----------->        analysts
# the             <----------->             the
# RBI             <----------->             RBI
# move            <----------->            move
# will            <----------->            will
# protect         <----------->         protect
# the             <----------->             the
# balancesheets   <----------->   balancesheets
# of              <----------->              of
# nationalised    <----------->    nationalised
# banks           <----------->           banks
# from            <----------->            from
# the             <----------->             the
# impact          <----------->          impact
# of              <----------->              of
# falling         <----------->         falling
# government      <----------->      government
# security        <----------->        security
# prices          <----------->          prices
# Nationalised    <----------->    Nationalised
# banks           <----------->           banks
# are             <----------->             are
# heavy           <----------->           heavy
# investors       <----------->       investors
# in              <----------->              in
# government      <----------->      government
# securities      <----------->      securities
# and             <----------->             and
# their           <----------->           their
# investments     <----------->     investments
# exceed          <----------->          exceed
# the             <----------->             the
# minimum         <----------->         minimum
# level           <----------->           level
# of              <----------->              of
# per             <----------->             per
# cent            <----------->            cent
# of              <----------->              of
# their           <----------->           their
# deposits        <----------->        deposits
# Presently       <----------->       Presently
# there           <----------->           there
# are             <----------->             are
# three           <----------->           three
# categories      <----------->      categories
# under           <----------->           under
# which           <----------->           which
# banks           <----------->           banks
# can             <----------->             can
# hold            <----------->            hold
# securities      <----------->      securities
# These           <----------->           These
# include         <----------->         include
# HTM             <----------->             HTM
# availableforsale <-----------> availableforsale
# and             <----------->             and
# heldfortrading  <----------->  heldfortrading
# categories      <----------->      categories
# The             <----------->             The
# RBI             <----------->             RBI
# regulations     <----------->     regulations
# stipulate       <----------->       stipulate
# that            <----------->            that
# banks           <----------->           banks
# must            <----------->            must
# mark            <----------->            mark
# to              <----------->              to
# market          <----------->          market
# their           <----------->           their
# holdings        <----------->        holdings
# in              <----------->              in
# the             <----------->             the
# availableforsale <-----------> availableforsale
# and             <----------->             and
# heldfortrading  <----------->  heldfortrading
# categories      <----------->      categories
# Market          <----------->          Market
# circles         <----------->         circles
# said            <----------->            said
# bank            <----------->            bank
# stocks          <----------->          stocks
# which           <----------->           which
# have            <----------->            have
# been            <----------->            been
# under           <----------->           under
# pressure        <----------->        pressure
# in              <----------->              in
# the             <----------->             the
# recent          <----------->          recent
# past            <----------->            past
# on              <----------->              on
# concerns        <----------->        concerns
# over            <----------->            over
# the             <----------->             the
# impact          <----------->          impact
# of              <----------->              of
# a               <----------->               a
# likely          <----------->          likely
# rise            <----------->            rise
# in              <----------->              in
# interest        <----------->        interest
# rates           <----------->           rates
# witnessed       <----------->       witnessed
# brisk           <----------->           brisk
# buying          <----------->          buying
# with            <----------->            with
# investors       <----------->       investors
# chasing         <----------->         chasing
# nationalised    <----------->    nationalised
# banks           <----------->           banks
# At              <----------->              At
# the             <----------->             the
# BSE             <----------->             BSE
# State           <----------->           State
# Bank            <----------->            Bank
# of              <----------->              of
# India           <----------->           India
# SBI             <----------->             SBI
# was             <----------->             was
# the             <----------->             the
# most            <----------->            most
# actively        <----------->        actively
# traded          <----------->          traded
# counter         <----------->         counter
# with            <----------->            with
# the             <----------->             the
# highest         <----------->         highest
# turnover        <----------->        turnover
# of              <----------->              of
# Rs              <----------->              Rs
# crore           <----------->           crore
# SBI             <----------->             SBI
# scrip           <----------->           scrip
# firmed          <----------->          firmed
# up              <----------->              up
# by              <----------->              by
# Rs              <----------->              Rs
# to              <----------->              to
# Rs              <----------->              Rs
# Bank            <----------->            Bank
# of              <----------->              of
# Baroda          <----------->          Baroda
# also            <----------->            also
# gained          <----------->          gained
# Rs              <----------->              Rs
# to              <----------->              to
# finish          <----------->          finish
# at              <----------->              at
# Rs              <----------->              Rs
# Corporation     <----------->     Corporation
# Bank            <----------->            Bank
# shares          <----------->          shares
# were            <----------->            were
# up              <----------->              up
# by              <----------->              by
# Rs              <----------->              Rs
# to              <----------->              to
# end             <----------->             end
# at              <----------->              at
# Rs              <----------->              Rs
# and             <----------->             and
# Canara          <----------->          Canara
# Bank            <----------->            Bank
# gained          <----------->          gained
# by              <----------->              by
# Rs              <----------->              Rs
# to              <----------->              to
# finish          <----------->          finish
# at              <----------->              at
# Rs              <----------->              Rs
# The             <----------->             The
# BSE             <----------->             BSE
# Bankex          <----------->          Bankex
# was             <----------->             was
# one             <----------->             one
# of              <----------->              of
# the             <----------->             the
# leading         <----------->         leading
# indices         <----------->         indices
# in              <----------->              in
# the             <----------->             the
# exchange        <----------->        exchange
# as              <----------->              as
# it              <----------->              it
# gained          <----------->          gained
# by              <----------->              by
# around          <----------->          around
# points          <----------->          points
# After           <----------->           After
# opening         <----------->         opening
# at              <----------->              at
# it              <----------->              it
# shot            <----------->            shot
# to              <----------->              to
# a               <----------->               a
# days            <----------->            days
# high            <----------->            high
# of              <----------->              of
# before          <----------->          before
# closing         <----------->         closing
# at              <----------->              at
# The             <----------->             The
# RBIs            <----------->            RBIs
# decision        <----------->        decision
# to              <----------->              to
# raise           <----------->           raise
# the             <----------->             the
# investment      <----------->      investment
# limits          <----------->          limits
# has             <----------->             has
# come            <----------->            come
# at              <----------->              at
# a               <----------->               a
# time            <----------->            time
# when            <----------->            when
# most            <----------->            most
# of              <----------->              of
# the             <----------->             the
# banks           <----------->           banks
# have            <----------->            have
# witnessed       <----------->       witnessed
# their           <----------->           their
# trading         <----------->         trading
# gains           <----------->           gains
# evaporate       <----------->       evaporate
# in              <----------->              in
# the             <----------->             the
# first           <----------->           first
# quarter         <----------->         quarter
# of              <----------->              of
# the             <----------->             the
# current         <----------->         current
# fiscal          <----------->          fiscal
# due             <----------->             due
# to              <----------->              to
# sustained       <----------->       sustained
# drop            <----------->            drop
# in              <----------->              in
# prices          <----------->          prices
# of              <----------->              of
# government      <----------->      government
# securities      <----------->      securities
# Treasury        <----------->        Treasury
# circles         <----------->         circles
# feel            <----------->            feel
# that            <----------->            that
# the             <----------->             the
# central         <----------->         central
# bank            <----------->            bank
# is              <----------->              is
# preparing       <----------->       preparing
# the             <----------->             the
# banking         <----------->         banking
# sector          <----------->          sector
# for             <----------->             for
# an              <----------->              an
# interest        <----------->        interest
# rate            <----------->            rate
# hike            <----------->            hike
# in              <----------->              in
# the             <----------->             the
# months          <----------->          months
# to              <----------->              to
# come            <----------->            come
# So              <----------->              So
# far             <----------->             far
# the             <----------->             the
# RBI             <----------->             RBI
# has             <----------->             has
# desisted        <----------->        desisted
# from            <----------->            from
# raising         <----------->         raising
# key             <----------->             key
# rates           <----------->           rates
# and             <----------->             and
# the             <----------->             the
# benchmark       <----------->       benchmark
# bank            <----------->            bank
# rate            <----------->            rate
# is              <----------->              is
# still           <----------->           still
# at              <----------->              at
# a               <----------->               a
# three           <----------->           three
# decade          <----------->          decade
# low             <----------->             low

# %% [markdown]
# ## Converting text to lowercase and removing stopwords:
# Here we convert all the tokens to lowercase using `lower()` function of `str` class.<br>
# We then remove all the stopword tokens by filtering from the `nltk` library's english *stopwords corpus* using `nltk.corpus.stopwords.words('english')`.

# %%
lowercaseTokens = [token.lower() for token in tokenizeNLTK]

stopwords = nltk.corpus.stopwords.words('english')

filteredText = [w for w in lowercaseTokens if not w in stopwords]

print(lowercaseTokens)
print(filteredText)
# Out:
# ['the', 'telegraph', 'calcutta', 'business', 'rbi', 'breather', 'for', 'urban', 'coop', 'banks', 'our', 'special', 'correspondent', 'mumbai', 'sept', 'the', 'reserve', 'bank', 'has', 'relaxed', 'loan', 'impairment', 'norms', 'for', 'urban', 'cooperative', 'banks', 'the', 'day', 'norm', 'relating', 'to', 'asset', 'classification', 'and', 'provisioning', 'will', 'now', 'be', 'applicable', 'to', 'gold', 'loans', 'and', 'small', 'loans', 'up', 'to', 'rs', 'lakh', 'only', 'from', 'the', 'financial', 'year', 'ending', 'march', 'till', 'then', 'these', 'loans', 'would', 'be', 'governed', 'by', 'the', 'day', 'impairment', 'norm', 'earlier', 'the', 'central', 'bank', 'had', 'advised', 'ucbs', 'to', 'apply', 'the', 'day', 'norm', 'from', 'the', 'financial', 'year', 'ending', 'march', 'the', 'decision', 'was', 'based', 'on', 'the', 'representations', 'by', 'ucbs', 'a', 'reserve', 'bank', 'release', 'said', 'here', 'today', 'rbi', 'governor', 'y', 'v', 'reddy', 'had', 'held', 'meeting', 'with', 'federations', 'of', 'cooperative', 'banks', 'on', 'september', 'where', 'ucbs', 'sought', 'relaxation', 'in', 'these', 'norms', 'in', 'the', 'meeting', 'specific', 'suggestions', 'were', 'placed', 'these', 'included', 'a', 'proposal', 'to', 'modify', 'prudential', 'regulations', 'including', 'deferring', 'the', 'application', 'of', 'day', 'norm', 'a', 'plan', 'to', 'exclude', 'gold', 'loans', 'and', 'loans', 'below', 'rs', 'lakh', 'from', 'these', 'norms', 'and', 'to', 'rationalise', 'procedures', 'governing', 'maintenance', 'of', 'cash', 'reserve', 'ratio', 'crr', 'the', 'representatives', 'also', 'requested', 'that', 'the', 'forthcoming', 'basel', 'ii', 'norms', 'are', 'applied', 'in', 'a', 'modified', 'form', 'to', 'suit', 'their', 'localised', 'nature', 'the', 'telegraph', 'calcutta', 'business', 'new', 'lic', 'pension', 'plans', 'a', 'staff', 'reporter', 'calcutta', 'sept', 'life', 'insurance', 'corporation', 'of', 'india', 'lic', 'plans', 'to', 'unveil', 'three', 'new', 'products', 'including', 'a', 'unitlinked', 'pension', 'plan', 'we', 'have', 'sought', 'approval', 'from', 'the', 'insurance', 'regulatory', 'and', 'development', 'authority', 'of', 'india', 'irda', 'for', 'the', 'approval', 'of', 'these', 'three', 'policies', 'and', 'will', 'launch', 'them', 'soon', 'after', 'we', 'receive', 'it', 'said', 'lic', 'zonal', 'manager', 'd', 'k', 'mehrotra', 'apart', 'from', 'the', 'unitlinked', 'pension', 'plan', 'the', 'schemes', 'would', 'include', 'a', 'childrens', 'plan', 'and', 'another', 'similar', 'to', 'jeevan', 'shree', 'for', 'high', 'networth', 'individuals', 'mehrotra', 'acknowledged', 'that', 'the', 'response', 'to', 'lics', 'existing', 'pension', 'schemes', 'was', 'not', 'very', 'encouraging', 'this', 'is', 'because', 'of', 'lack', 'of', 'awareness', 'among', 'employees', 'in', 'rural', 'and', 'the', 'unorganised', 'sector', 'said', 'mehrotra', 'however', 'the', 'company', 'is', 'planning', 'to', 'increase', 'awareness', 'among', 'these', 'sections', 'of', 'people', 'through', 'a', 'number', 'of', 'programmes', 'to', 'be', 'addressed', 'by', 'agents', 'and', 'marketing', 'people', 'mehrotra', 'added', 'till', 'august', 'the', 'corporation', 'had', 'sold', 'a', 'total', 'of', 'pension', 'policies', 'with', 'a', 'premium', 'income', 'of', 'rs', 'crore', 'in', 'the', 'eastern', 'zone', 'lic', 'had', 'sold', 'policies', 'in', 'the', 'period', 'between', 'april', 'and', 'august', 'with', 'a', 'total', 'premium', 'income', 'of', 'rs', 'crore', 'during', 'the', 'financial', 'year', 'lic', 'had', 'sold', 'a', 'total', 'of', 'lakh', 'pension', 'policies', 'with', 'a', 'premium', 'income', 'of', 'rs', 'crore', 'in', 'which', 'the', 'share', 'of', 'the', 'eastern', 'zone', 'was', 'policies', 'and', 'rs', 'crore', 'in', 'premium', 'income', 'mehrotra', 'said', 'that', 'the', 'corporation', 'would', 'give', 'special', 'emphasis', 'on', 'increasing', 'distribution', 'channels', 'to', 'maintain', 'its', 'market', 'share', 'and', 'also', 'increase ...
# ['telegraph', 'calcutta', 'business', 'rbi', 'breather', 'urban', 'coop', 'banks', 'special', 'correspondent', 'mumbai', 'sept', 'reserve', 'bank', 'relaxed', 'loan', 'impairment', 'norms', 'urban', 'cooperative', 'banks', 'day', 'norm', 'relating', 'asset', 'classification', 'provisioning', 'applicable', 'gold', 'loans', 'small', 'loans', 'rs', 'lakh', 'financial', 'year', 'ending', 'march', 'till', 'loans', 'would', 'governed', 'day', 'impairment', 'norm', 'earlier', 'central', 'bank', 'advised', 'ucbs', 'apply', 'day', 'norm', 'financial', 'year', 'ending', 'march', 'decision', 'based', 'representations', 'ucbs', 'reserve', 'bank', 'release', 'said', 'today', 'rbi', 'governor', 'v', 'reddy', 'held', 'meeting', 'federations', 'cooperative', 'banks', 'september', 'ucbs', 'sought', 'relaxation', 'norms', 'meeting', 'specific', 'suggestions', 'placed', 'included', 'proposal', 'modify', 'prudential', 'regulations', 'including', 'deferring', 'application', 'day', 'norm', 'plan', 'exclude', 'gold', 'loans', 'loans', 'rs', 'lakh', 'norms', 'rationalise', 'procedures', 'governing', 'maintenance', 'cash', 'reserve', 'ratio', 'crr', 'representatives', 'also', 'requested', 'forthcoming', 'basel', 'ii', 'norms', 'applied', 'modified', 'form', 'suit', 'localised', 'nature', 'telegraph', 'calcutta', 'business', 'new', 'lic', 'pension', 'plans', 'staff', 'reporter', 'calcutta', 'sept', 'life', 'insurance', 'corporation', 'india', 'lic', 'plans', 'unveil', 'three', 'new', 'products', 'including', 'unitlinked', 'pension', 'plan', 'sought', 'approval', 'insurance', 'regulatory', 'development', 'authority', 'india', 'irda', 'approval', 'three', 'policies', 'launch', 'soon', 'receive', 'said', 'lic', 'zonal', 'manager', 'k', 'mehrotra', 'apart', 'unitlinked', 'pension', 'plan', 'schemes', 'would', 'include', 'childrens', 'plan', 'another', 'similar', 'jeevan', 'shree', 'high', 'networth', 'individuals', 'mehrotra', 'acknowledged', 'response', 'lics', 'existing', 'pension', 'schemes', 'encouraging', 'lack', 'awareness', 'among', 'employees', 'rural', 'unorganised', 'sector', 'said', 'mehrotra', 'however', 'company', 'planning', 'increase', 'awareness', 'among', 'sections', 'people', 'number', 'programmes', 'addressed', 'agents', 'marketing', 'people', 'mehrotra', 'added', 'till', 'august', 'corporation', 'sold', 'total', 'pension', 'policies', 'premium', 'income', 'rs', 'crore', 'eastern', 'zone', 'lic', 'sold', 'policies', 'period', 'april', 'august', 'total', 'premium', 'income', 'rs', 'crore', 'financial', 'year', 'lic', 'sold', 'total', 'lakh', 'pension', 'policies', 'premium', 'income', 'rs', 'crore', 'share', 'eastern', 'zone', 'policies', 'rs', 'crore', 'premium', 'income', 'mehrotra', 'said', 'corporation', 'would', 'give', 'special', 'emphasis', 'increasing', 'distribution', 'channels', 'maintain', 'market', 'share', 'also', 'increase', 'popularity', 'pension', 'schemes', 'lic', 'markets', 'products', 'outlets', 'banks', 'namely', 'uco', 'bank', 'corporation', 'bank', 'allahabad', 'bank', 'west', 'bengal', 'state', 'cooperative', 'bank', 'licensed', 'corporate', 'agents', 'market', 'products', 'outlets', 'august', 'eastern', 'zone', 'earned', 'premium', 'income', 'rs', 'crore', 'selling', 'lakh', 'policies', 'recording', 'growth', 'per', 'cent', 'per', 'cent', 'premium', 'policies', 'respectively', 'bima', 'plus', 'fetched', 'premium', 'rs', 'crore', 'seven', 'important', 'new', 'plans', 'earned', 'premium', 'rs', 'crore', 'telegraph', 'calcutta', 'business', 'advisers', 'help', 'wbidc', 'sell', 'bad', 'assets', 'sutanuka', 'ghosal', 'calcutta', 'sept', 'west', 'bengal', 'industrial', 'development', 'corporation', 'wbidc', 'appoint', 'advisers', 'help', 'dispose', 'assets', 'liquidation', 'decision', 'taken', 'corporations', 'board', 'meeting', 'held', 'last', 'month', 'assets', 'liquidation', 'wbidc', 'wants', 'generate', 'revenues', 'corporation', 'soon', 'float', 'tender', 'inviting', 'bids', 'advisers', 'paid', 'commission', 'basis' ...

# %% [markdown]
# ## Performing Stemming using Porter Stemmer:
# Here we perform Stemming process on our word tokens.<br>
# We will use Porter Stemmer for this process.
# <br>
# <br>
# The output shows the result of stemming using Porter Stemmer on each word tokens. We can observe that stemming is not a perfect way to convert surface word to its root word as many words are incorrectly stemmed to the root word.

# %%
# Creating a PorterStemmer object
ps = nltk.stem.PorterStemmer()
stemmedWords = []
print("Word Token".ljust(15), "---->", "Stem".rjust(15))
print("\n")
for token in filteredText:
  stem = ps.stem(token)
  print(token.ljust(15), "---->", stem.rjust(15))
  stemmedWords.append(stem)
# Out:
# Word Token      ---->            Stem
#
#
# telegraph       ---->       telegraph
# calcutta        ---->        calcutta
# business        ---->            busi
# rbi             ---->             rbi
# breather        ---->        breather
# urban           ---->           urban
# coop            ---->            coop
# banks           ---->            bank
# special         ---->         special
# correspondent   ---->      correspond
# mumbai          ---->          mumbai
# sept            ---->            sept
# reserve         ---->          reserv
# bank            ---->            bank
# relaxed         ---->           relax
# loan            ---->            loan
# impairment      ---->          impair
# norms           ---->            norm
# urban           ---->           urban
# cooperative     ---->          cooper
# banks           ---->            bank
# day             ---->             day
# norm            ---->            norm
# relating        ---->           relat
# asset           ---->           asset
# classification  ---->         classif
# provisioning    ---->          provis
# applicable      ---->          applic
# gold            ---->            gold
# loans           ---->            loan
# small           ---->           small
# loans           ---->            loan
# rs              ---->              rs
# lakh            ---->            lakh
# financial       ---->         financi
# year            ---->            year
# ending          ---->             end
# march           ---->           march
# till            ---->            till
# loans           ---->            loan
# would           ---->           would
# governed        ---->          govern
# day             ---->             day
# impairment      ---->          impair
# norm            ---->            norm
# earlier         ---->         earlier
# central         ---->         central
# bank            ---->            bank
# advised         ---->           advis
# ucbs            ---->             ucb
# apply           ---->           appli
# day             ---->             day
# norm            ---->            norm
# financial       ---->         financi
# year            ---->            year
# ending          ---->             end
# march           ---->           march
# decision        ---->           decis
# based           ---->            base
# representations ---->       represent
# ucbs            ---->             ucb
# reserve         ---->          reserv
# bank            ---->            bank
# release         ---->          releas
# said            ---->            said
# today           ---->           today
# rbi             ---->             rbi
# governor        ---->        governor
# v               ---->               v
# reddy           ---->           reddi
# held            ---->            held
# meeting         ---->            meet
# federations     ---->           feder
# cooperative     ---->          cooper
# banks           ---->            bank
# september       ---->         septemb
# ucbs            ---->             ucb
# sought          ---->          sought
# relaxation      ---->           relax
# norms           ---->            norm
# meeting         ---->            meet
# specific        ---->          specif
# suggestions     ---->         suggest
# placed          ---->           place
# included        ---->          includ
# proposal        ---->          propos
# modify          ---->          modifi
# prudential      ---->        prudenti
# regulations     ---->           regul
# including       ---->          includ
# deferring       ---->           defer
# application     ---->          applic
# day             ---->             day
# norm            ---->            norm
# plan            ---->            plan
# exclude         ---->          exclud
# gold            ---->            gold
# loans           ---->            loan
# loans           ---->            loan
# rs              ---->              rs
# lakh            ---->            lakh
# norms           ---->            norm
# rationalise     ---->      rationalis
# procedures      ---->        procedur
# governing       ---->          govern
# maintenance     ---->         mainten
# cash            ---->            cash
# reserve         ---->          reserv
# ratio           ---->           ratio
# crr             ---->             crr
# representatives ---->          repres
# also            ---->            also
# requested       ---->         request
# forthcoming     ---->        forthcom
# basel           ---->           basel
# ii              ---->              ii
# norms           ---->            norm
# applied         ---->           appli
# modified        ---->          modifi
# form            ---->            form
# suit            ---->            suit
# localised       ---->         localis
# nature          ---->           natur
# telegraph       ---->       telegraph
# calcutta        ---->        calcutta
# business        ---->            busi
# new             ---->             new
# lic             ---->             lic
# pension         ---->         pension
# plans           ---->            plan
# staff           ---->           staff
# reporter        ---->          report
# calcutta        ---->        calcutta
# sept            ---->            sept
# life            ---->            life
# insurance       ---->           insur
# corporation     ---->          corpor
# india           ---->           india
# lic             ---->             lic
# plans           ---->            plan
# unveil          ---->          unveil
# three           ---->           three
# new             ---->             new
# products        ---->         product
# including       ---->          includ
# unitlinked      ---->        unitlink
# pension         ---->         pension
# plan            ---->            plan
# sought          ---->          sought
# approval        ---->          approv
# insurance       ---->           insur
# regulatory      ---->      regulatori
# development     ---->         develop
# authority       ---->          author
# india           ---->           india
# irda            ---->            irda
# approval        ---->          approv
# three           ---->           three
# policies        ---->          polici
# launch          ---->          launch
# soon            ---->            soon
# receive         ---->          receiv
# said            ---->            said
# lic             ---->             lic
# zonal           ---->           zonal
# manager         ---->           manag
# k               ---->               k
# mehrotra        ---->        mehrotra
# apart           ---->           apart
# unitlinked      ---->        unitlink
# pension         ---->         pension
# plan            ---->            plan
# schemes         ---->          scheme
# would           ---->           would
# include         ---->          includ
# childrens       ---->        children
# plan            ---->            plan
# another         ---->           anoth
# similar         ---->         similar
# jeevan          ---->          jeevan
# shree           ---->           shree
# high            ---->            high
# networth        ---->        networth
# individuals     ---->        individu
# mehrotra        ---->        mehrotra
# acknowledged    ---->      acknowledg
# response        ---->         respons
# lics            ---->             lic
# existing        ---->           exist
# pension         ---->         pension
# schemes         ---->          scheme
# encouraging     ---->        encourag
# lack            ---->            lack
# awareness       ---->            awar
# among           ---->           among
# employees       ---->         employe
# rural           ---->           rural
# unorganised     ---->       unorganis
# sector          ---->          sector
# said            ---->            said
# mehrotra        ---->        mehrotra
# however         ---->           howev
# company         ---->         compani
# planning        ---->            plan
# increase        ---->         increas
# awareness       ---->            awar
# among           ---->           among
# sections        ---->         section
# people          ---->           peopl
# number          ---->          number
# programmes      ---->        programm
# addressed       ---->         address
# agents          ---->           agent
# marketing       ---->          market
# people          ---->           peopl
# mehrotra        ---->        mehrotra
# added           ---->              ad
# till            ---->            till
# august          ---->          august
# corporation     ---->          corpor
# sold            ---->            sold
# total           ---->           total
# pension         ---->         pension
# policies        ---->          polici
# premium         ---->         premium
# income          ---->           incom
# rs              ---->              rs
# crore           ---->           crore
# eastern         ---->         eastern
# zone            ---->            zone
# lic             ---->             lic
# sold            ---->            sold
# policies        ---->          polici
# period          ---->          period
# april           ---->           april
# august          ---->          august
# total           ---->           total
# premium         ---->         premium
# income          ---->           incom
# rs              ---->              rs
# crore           ---->           crore
# financial       ---->         financi
# year            ---->            year
# lic             ---->             lic
# sold            ---->            sold
# total           ---->           total
# lakh            ---->            lakh
# pension         ---->         pension
# policies        ---->          polici
# premium         ---->         premium
# income          ---->           incom
# rs              ---->              rs
# crore           ---->           crore
# share           ---->           share
# eastern         ---->         eastern
# zone            ---->            zone
# policies        ---->          polici
# rs              ---->              rs
# crore           ---->           crore
# premium         ---->         premium
# income          ---->           incom
# mehrotra        ---->        mehrotra
# said            ---->            said
# corporation     ---->          corpor
# would           ---->           would
# give            ---->            give
# special         ---->         special
# emphasis        ---->         emphasi
# increasing      ---->         increas
# distribution    ---->       distribut
# channels        ---->         channel
# maintain        ---->        maintain
# market          ---->          market
# share           ---->           share
# also            ---->            also
# increase        ---->         increas
# popularity      ---->         popular
# pension         ---->         pension
# schemes         ---->          scheme
# lic             ---->             lic
# markets         ---->          market
# products        ---->         product
# outlets         ---->          outlet
# banks           ---->            bank
# namely          ---->            name
# uco             ---->             uco
# bank            ---->            bank
# corporation     ---->          corpor
# bank            ---->            bank
# allahabad       ---->       allahabad
# bank            ---->            bank
# west            ---->            west
# bengal          ---->          bengal
# state           ---->           state
# cooperative     ---->          cooper
# bank            ---->            bank
# licensed        ---->          licens
# corporate       ---->          corpor
# agents          ---->           agent
# market          ---->          market
# products        ---->         product
# outlets         ---->          outlet
# august          ---->          august
# eastern         ---->         eastern
# zone            ---->            zone
# earned          ---->            earn
# premium         ---->         premium
# income          ---->           incom
# rs              ---->              rs
# crore           ---->           crore
# selling         ---->            sell
# lakh            ---->            lakh
# policies        ---->          polici
# recording       ---->          record
# growth          ---->          growth
# per             ---->             per
# cent            ---->            cent
# per             ---->             per
# cent            ---->            cent
# premium         ---->         premium
# policies        ---->          polici
# respectively    ---->         respect
# bima            ---->            bima
# plus            ---->             plu
# fetched         ---->           fetch
# premium         ---->         premium
# rs              ---->              rs
# crore           ---->           crore
# seven           ---->           seven
# important       ---->          import
# new             ---->             new
# plans           ---->            plan
# earned          ---->            earn
# premium         ---->         premium
# rs              ---->              rs
# crore           ---->           crore
# telegraph       ---->       telegraph
# calcutta        ---->        calcutta
# business        ---->            busi
# advisers        ---->           advis
# help            ---->            help
# wbidc           ---->           wbidc
# sell            ---->            sell
# bad             ---->             bad
# assets          ---->           asset
# sutanuka        ---->        sutanuka
# ghosal          ---->          ghosal
# calcutta        ---->        calcutta
# sept            ---->            sept
# west            ---->            west
# bengal          ---->          bengal
# industrial      ---->        industri
# development     ---->         develop
# corporation     ---->          corpor
# wbidc           ---->           wbidc
# appoint         ---->         appoint
# advisers        ---->           advis
# help            ---->            help
# dispose         ---->          dispos
# assets          ---->           asset
# liquidation     ---->          liquid
# decision        ---->           decis
# taken           ---->           taken
# corporations    ---->          corpor
# board           ---->           board
# meeting         ---->            meet
# held            ---->            held
# last            ---->            last
# month           ---->           month
# assets          ---->           asset
# liquidation     ---->          liquid
# wbidc           ---->           wbidc
# wants           ---->            want
# generate        ---->           gener
# revenues        ---->          revenu
# corporation     ---->          corpor
# soon            ---->            soon
# float           ---->           float
# tender          ---->          tender
# inviting        ---->           invit
# bids            ---->             bid
# advisers        ---->           advis
# paid            ---->            paid
# commission      ---->         commiss
# basis           ---->            basi
# huge            ---->            huge
# assets          ---->           asset
# nonperforming   ---->      nonperform
# companies       ---->         compani
# liquidation     ---->          liquid
# wbidc           ---->           wbidc
# exposure        ---->         exposur
# companies       ---->         compani
# want            ---->            want
# unlock          ---->          unlock
# idle            ---->             idl
# assets          ---->           asset
# enhance         ---->          enhanc
# revenue         ---->          revenu
# flow            ---->            flow
# advisers        ---->           advis
# help            ---->            help
# us              ---->              us
# selling         ---->            sell
# assets          ---->           asset
# corporation     ---->          corpor
# pay             ---->             pay
# good            ---->            good
# commissions     ---->         commiss
# said            ---->            said
# senior          ---->          senior
# wbidc           ---->           wbidc
# official        ---->          offici
# wbidc           ---->           wbidc
# consciously     ---->       conscious
# decided         ---->           decid
# increase        ---->         increas
# standard        ---->        standard
# assets          ---->           asset
# order           ---->           order
# reduce          ---->           reduc
# net             ---->             net
# nonperforming   ---->      nonperform
# asset           ---->           asset
# net             ---->             net
# asset           ---->           asset
# ratio           ---->           ratio
# corporation     ---->          corpor
# planning        ---->            plan
# increase        ---->         increas
# exposure        ---->         exposur
# forthcoming     ---->        forthcom
# projects        ---->         project
# last            ---->            last
# couple          ---->           coupl
# years           ---->            year
# wbidc           ---->           wbidc
# invested        ---->          invest
# heavily         ---->         heavili
# last            ---->            last
# major           ---->           major
# rs              ---->              rs
# crore           ---->           crore
# ramrupai        ---->        ramrupai
# steel           ---->           steel
# sources         ---->           sourc
# said            ---->            said
# corporation     ---->          corpor
# may             ---->             may
# increase        ---->         increas
# exposure        ---->         exposur
# rs              ---->              rs
# crore           ---->           crore
# certain         ---->         certain
# projects        ---->         project
# present         ---->         present
# three           ---->           three
# steel           ---->           steel
# cement          ---->          cement
# project         ---->         project
# wbidcs          ---->           wbidc
# platter         ---->         platter
# however         ---->           howev
# investment      ---->          invest
# form            ---->            form
# loans           ---->            loan
# wbidc           ---->           wbidc
# invest          ---->          invest
# equity          ---->          equiti
# big             ---->             big
# way             ---->             way
# unless          ---->          unless
# big             ---->             big
# project         ---->         project
# wbidc           ---->           wbidc
# pick            ---->            pick
# equity          ---->          equiti
# buy             ---->             buy
# per             ---->             per
# cent            ---->            cent
# kulpi           ---->           kulpi
# port            ---->            port
# developed       ---->         develop
# bengal          ---->          bengal
# government      ---->          govern
# p               ---->               p
# amp             ---->             amp
# bengal          ---->          bengal
# port            ---->            port
# sources         ---->           sourc
# added           ---->              ad
# corporation     ---->          corpor
# may             ---->             may
# also            ---->            also
# buy             ---->             buy
# stake           ---->           stake
# tatas           ---->            tata
# coke            ---->            coke
# oven            ---->            oven
# project         ---->         project
# slated          ---->           slate
# come            ---->            come
# haldia          ---->          haldia
# wbidc           ---->           wbidc
# disbursed       ---->         disburs
# rs              ---->              rs
# crore           ---->           crore
# loans           ---->            loan
# year            ---->            year
# target          ---->          target
# rs              ---->              rs
# crore           ---->           crore
# corporation     ---->          corpor
# also            ---->            also
# trying          ---->             tri
# cut             ---->             cut
# bad             ---->             bad
# assets          ---->           asset
# wbidc           ---->           wbidc
# trimmed         ---->            trim
# bad             ---->             bad
# nonperforming   ---->      nonperform
# assets          ---->           asset
# npas            ---->             npa
# rs              ---->              rs
# crore           ---->           crore
# year            ---->            year
# target          ---->          target
# rs              ---->              rs
# crore           ---->           crore
# wbidc           ---->           wbidc
# decided         ---->           decid
# raise           ---->            rais
# money           ---->           money
# receivables     ---->          receiv
# part            ---->            part
# securitisation  ---->       securitis
# exercise        ---->         exercis
# icici           ---->           icici
# bank            ---->            bank
# agreed          ---->            agre
# provide         ---->          provid
# rs              ---->              rs
# crore           ---->           crore
# loan            ---->            loan
# receivables     ---->          receiv
# coupon          ---->          coupon
# rate            ---->            rate
# per             ---->             per
# cent            ---->            cent
# corporation     ---->          corpor
# lend            ---->            lend
# money           ---->           money
# higher          ---->          higher
# interest        ---->        interest
# per             ---->             per
# cent            ---->            cent
# thereby         ---->         therebi
# augmenting      ---->         augment
# revenue         ---->          revenu
# state           ---->           state
# bank            ---->            bank
# india           ---->           india
# well            ---->            well
# uti             ---->             uti
# bank            ---->            bank
# keen            ---->            keen
# provide         ---->          provid
# loans           ---->            loan
# receivables     ---->          receiv
# interest        ---->        interest
# per             ---->             per
# cent            ---->            cent
# idbi            ---->            idbi
# also            ---->            also
# keen            ---->            keen
# provide         ---->          provid
# us              ---->              us
# loans           ---->            loan
# much            ---->            much
# lower           ---->           lower
# interest        ---->        interest
# per             ---->             per
# cent            ---->            cent
# talks           ---->            talk
# sources         ---->           sourc
# added           ---->              ad
# telegraph       ---->       telegraph
# calcutta        ---->        calcutta
# business        ---->            busi
# eyes            ---->             eye
# greenspan       ---->       greenspan
# week            ---->            week
# greenspan       ---->       greenspan
# focus           ---->            focu
# london          ---->          london
# sept            ---->            sept
# reuters         ---->          reuter
# federal         ---->           feder
# reserve         ---->          reserv
# chairman        ---->        chairman
# alan            ---->            alan
# greenspans      ---->       greenspan
# testimony       ---->       testimoni
# capitol         ---->         capitol
# hill            ---->            hill
# midweek         ---->         midweek
# main            ---->            main
# draw            ---->            draw
# global          ---->          global
# financial       ---->         financi
# markets         ---->          market
# week            ---->            week
# absence         ---->          absenc
# significant     ---->        signific
# data            ---->            data
# either          ---->          either
# side            ---->            side
# atlantic        ---->          atlant
# analysts        ---->         analyst
# said            ---->            said
# ruthlessly      ---->      ruthlessli
# put             ---->             put
# green           ---->           green
# spans           ---->            span
# testimony       ---->       testimoni
# real            ---->            real
# factor          ---->          factor
# matters         ---->          matter
# next            ---->            next
# week            ---->            week
# global          ---->          global
# foreign         ---->         foreign
# exchange        ---->         exchang
# debt            ---->            debt
# markets         ---->          market
# said            ---->            said
# smith           ---->           smith
# economist       ---->       economist
# icap            ---->            icap
# london          ---->          london
# greenspan       ---->       greenspan
# speak           ---->           speak
# house           ---->            hous
# representatives ---->          repres
# budget          ---->          budget
# committee       ---->        committe
# next            ---->            next
# wednesday       ---->       wednesday
# us              ---->              us
# august          ---->          august
# nonfarm         ---->         nonfarm
# payrolls        ---->          payrol
# report          ---->          report
# friday          ---->          friday
# preserved       ---->         preserv
# prospect        ---->        prospect
# rising          ---->            rise
# federal         ---->           feder
# funds           ---->            fund
# rate            ---->            rate
# analysts        ---->         analyst
# said            ---->            said
# would           ---->           would
# lend            ---->            lend
# support         ---->         support
# central         ---->         central
# bankers         ---->          banker
# outlook         ---->         outlook
# worlds          ---->           world
# biggest         ---->         biggest
# economy         ---->         economi
# although        ---->        although
# employers       ---->          employ
# added           ---->              ad
# payrolls        ---->          payrol
# august          ---->          august
# median          ---->          median
# forecast        ---->        forecast
# upward          ---->          upward
# revisions       ---->           revis
# june            ---->            june
# july            ---->            juli
# data            ---->            data
# debt            ---->            debt
# markets         ---->          market
# dived           ---->            dive
# figures         ---->           figur
# nonfarm         ---->         nonfarm
# payrolls        ---->          payrol
# dont            ---->            dont
# change          ---->           chang
# anything        ---->           anyth
# provide         ---->          provid
# greenspan       ---->       greenspan
# ammunition      ---->         ammunit
# say             ---->             say
# economy         ---->         economi
# rebounding      ---->         rebound
# leave           ---->            leav
# scope           ---->           scope
# tightening      ---->         tighten
# rates           ---->            rate
# said            ---->            said
# marc            ---->            marc
# ostwald         ---->         ostwald
# bond            ---->            bond
# broker          ---->          broker
# monument        ---->        monument
# securities      ---->           secur
# london          ---->          london
# us              ---->              us
# rates           ---->            rate
# last            ---->            last
# hiked           ---->            hike
# basis           ---->            basi
# points          ---->           point
# per             ---->             per
# cent            ---->            cent
# august          ---->          august
# midyear         ---->         midyear
# nestled         ---->           nestl
# per             ---->             per
# cent            ---->            cent
# year            ---->            year
# lowest          ---->          lowest
# since           ---->            sinc
# mids            ---->             mid
# greenspan       ---->       greenspan
# say             ---->             say
# tightening      ---->         tighten
# necessary       ---->       necessari
# remove          ---->           remov
# unnecessary     ---->     unnecessari
# accommodation   ---->        accommod
# given           ---->           given
# market          ---->          market
# resulted        ---->          result
# negative        ---->             neg
# real            ---->            real
# interest        ---->        interest
# rates           ---->            rate
# added           ---->              ad
# since           ---->            sinc
# testimony       ---->       testimoni
# july            ---->            juli
# noted           ---->            note
# payrolls        ---->          payrol
# averaged        ---->          averag
# per             ---->             per
# month           ---->           month
# past            ---->            past
# six             ---->             six
# months          ---->           month
# average         ---->          averag
# reading         ---->            read
# slowed          ---->            slow
# three           ---->           three
# months          ---->           month
# july            ---->            juli
# said            ---->            said
# research        ---->        research
# note            ---->            note
# friday          ---->          friday
# hsbc            ---->            hsbc
# bank            ---->            bank
# greenspan       ---->       greenspan
# likely          ---->            like
# blame           ---->           blame
# recent          ---->          recent
# disappointment  ---->      disappoint
# high            ---->            high
# oil             ---->             oil
# price           ---->           price
# recent          ---->          recent
# pullback        ---->        pullback
# energy          ---->          energi
# prices          ---->           price
# could           ---->           could
# give            ---->            give
# breathing       ---->          breath
# roomto          ---->          roomto
# remain          ---->          remain
# growth          ---->          growth
# bullish         ---->         bullish
# note            ---->            note
# added           ---->              ad
# telegraph       ---->       telegraph
# calcutta        ---->        calcutta
# business        ---->            busi
# rbi             ---->             rbi
# fuels           ---->            fuel
# rally           ---->           ralli
# bank            ---->            bank
# stocks          ---->           stock
# special         ---->         special
# correspondent   ---->      correspond
# mumbai          ---->          mumbai
# sept            ---->            sept
# bank            ---->            bank
# shares          ---->           share
# rallied         ---->           ralli
# stock           ---->           stock
# exchanges       ---->         exchang
# today           ---->           today
# reserve         ---->          reserv
# bank            ---->            bank
# india           ---->           india
# relaxed         ---->           relax
# limits          ---->           limit
# banks           ---->            bank
# bond            ---->            bond
# investments     ---->          invest
# yesterday       ---->       yesterday
# rbi             ---->             rbi
# move            ---->            move
# expected        ---->          expect
# positive        ---->           posit
# impact          ---->          impact
# balancesheet    ---->    balancesheet
# public          ---->          public
# sector          ---->          sector
# banks           ---->            bank
# would           ---->           would
# cushion         ---->         cushion
# falling         ---->            fall
# government      ---->          govern
# security        ---->           secur
# prices          ---->           price
# rbi             ---->             rbi
# allowed         ---->           allow
# banks           ---->            bank
# exceed          ---->          exceed
# per             ---->             per
# cent            ---->            cent
# limit           ---->           limit
# investments     ---->          invest
# heldtomaturity  ---->     heldtomatur
# htm             ---->             htm
# category        ---->        categori
# provided        ---->          provid
# excess          ---->          excess
# comprises       ---->         compris
# statutory       ---->       statutori
# liquidity       ---->          liquid
# ratio           ---->           ratio
# slr             ---->             slr
# securities      ---->           secur
# central         ---->         central
# bank            ---->            bank
# also            ---->            also
# stipulated      ---->          stipul
# total           ---->           total
# slr             ---->             slr
# securities      ---->           secur
# held            ---->            held
# htm             ---->             htm
# category        ---->        categori
# per             ---->             per
# cent            ---->            cent
# demand          ---->          demand
# time            ---->            time
# liabilities     ---->          liabil
# dtl             ---->             dtl
# last            ---->            last
# friday          ---->          friday
# second          ---->          second
# preceding       ---->          preced
# fortnight       ---->       fortnight
# according       ---->          accord
# analysts        ---->         analyst
# rbi             ---->             rbi
# move            ---->            move
# protect         ---->         protect
# balancesheets   ---->    balancesheet
# nationalised    ---->      nationalis
# banks           ---->            bank
# impact          ---->          impact
# falling         ---->            fall
# government      ---->          govern
# security        ---->           secur
# prices          ---->           price
# nationalised    ---->      nationalis
# banks           ---->            bank
# heavy           ---->           heavi
# investors       ---->        investor
# government      ---->          govern
# securities      ---->           secur
# investments     ---->          invest
# exceed          ---->          exceed
# minimum         ---->         minimum
# level           ---->           level
# per             ---->             per
# cent            ---->            cent
# deposits        ---->         deposit
# presently       ---->         present
# three           ---->           three
# categories      ---->        categori
# banks           ---->            bank
# hold            ---->            hold
# securities      ---->           secur
# include         ---->          includ
# htm             ---->             htm
# availableforsale ----> availableforsal
# heldfortrading  ---->     heldfortrad
# categories      ---->        categori
# rbi             ---->             rbi
# regulations     ---->           regul
# stipulate       ---->          stipul
# banks           ---->            bank
# must            ---->            must
# mark            ---->            mark
# market          ---->          market
# holdings        ---->            hold
# availableforsale ----> availableforsal
# heldfortrading  ---->     heldfortrad
# categories      ---->        categori
# market          ---->          market
# circles         ---->           circl
# said            ---->            said
# bank            ---->            bank
# stocks          ---->           stock
# pressure        ---->         pressur
# recent          ---->          recent
# past            ---->            past
# concerns        ---->         concern
# impact          ---->          impact
# likely          ---->            like
# rise            ---->            rise
# interest        ---->        interest
# rates           ---->            rate
# witnessed       ---->             wit
# brisk           ---->           brisk
# buying          ---->             buy
# investors       ---->        investor
# chasing         ---->           chase
# nationalised    ---->      nationalis
# banks           ---->            bank
# bse             ---->             bse
# state           ---->           state
# bank            ---->            bank
# india           ---->           india
# sbi             ---->             sbi
# actively        ---->           activ
# traded          ---->           trade
# counter         ---->         counter
# highest         ---->         highest
# turnover        ---->          turnov
# rs              ---->              rs
# crore           ---->           crore
# sbi             ---->             sbi
# scrip           ---->           scrip
# firmed          ---->            firm
# rs              ---->              rs
# rs              ---->              rs
# bank            ---->            bank
# baroda          ---->          baroda
# also            ---->            also
# gained          ---->            gain
# rs              ---->              rs
# finish          ---->          finish
# rs              ---->              rs
# corporation     ---->          corpor
# bank            ---->            bank
# shares          ---->           share
# rs              ---->              rs
# end             ---->             end
# rs              ---->              rs
# canara          ---->          canara
# bank            ---->            bank
# gained          ---->            gain
# rs              ---->              rs
# finish          ---->          finish
# rs              ---->              rs
# bse             ---->             bse
# bankex          ---->          bankex
# one             ---->             one
# leading         ---->            lead
# indices         ---->           indic
# exchange        ---->         exchang
# gained          ---->            gain
# around          ---->          around
# points          ---->           point
# opening         ---->            open
# shot            ---->            shot
# days            ---->             day
# high            ---->            high
# closing         ---->           close
# rbis            ---->             rbi
# decision        ---->           decis
# raise           ---->            rais
# investment      ---->          invest
# limits          ---->           limit
# come            ---->            come
# time            ---->            time
# banks           ---->            bank
# witnessed       ---->             wit
# trading         ---->           trade
# gains           ---->            gain
# evaporate       ---->          evapor
# first           ---->           first
# quarter         ---->         quarter
# current         ---->         current
# fiscal          ---->          fiscal
# due             ---->             due
# sustained       ---->         sustain
# drop            ---->            drop
# prices          ---->           price
# government      ---->          govern
# securities      ---->           secur
# treasury        ---->        treasuri
# circles         ---->           circl
# feel            ---->            feel
# central         ---->         central
# bank            ---->            bank
# preparing       ---->          prepar
# banking         ---->            bank
# sector          ---->          sector
# interest        ---->        interest
# rate            ---->            rate
# hike            ---->            hike
# months          ---->           month
# come            ---->            come
# far             ---->             far
# rbi             ---->             rbi
# desisted        ---->          desist
# raising         ---->            rais
# key             ---->             key
# rates           ---->            rate
# benchmark       ---->       benchmark
# bank            ---->            bank
# rate            ---->            rate
# still           ---->           still
# three           ---->           three
# decade          ---->           decad
# low             ---->             low

# %% [markdown]
# ## Performing Lemmatization on the word tokens:
# Here we use `nltk` library's `WordNetLemmatizer` to lemmatize surface word tokens back to their root words.<br>
#
# `WordNetLemmatizer` accepts a second argument of POS tag to more accurately convert the word passed to the lemmatizer.<br>
#
# To get POS tag for every word tokens we have defined a function which will take the word as an argument and return its appropriate POS tag using `nltk.pos_tag()` function.

# %%
# Creating WordNetLemmatizer object for lemmatization of words
lemmatizer = nltk.stem.WordNetLemmatizer()
lemmatizedWords = []

# Defining a function to return an appropriate POS tag to pass
# as a parameter to lemmatizer.lemmatize()
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": nltk.corpus.wordnet.ADJ,
                "N": nltk.corpus.wordnet.NOUN,
                "V": nltk.corpus.wordnet.VERB,
                "R": nltk.corpus.wordnet.ADV}

    return tag_dict.get(tag, nltk.corpus.wordnet.NOUN)

print("Word Token".ljust(15), "---->", "Lemmatization".rjust(15))
print("\n")
for token in filteredText:
  lemmatized = lemmatizer.lemmatize(token, get_wordnet_pos(token))
  print(token.ljust(15), "---->", lemmatized.rjust(15))
  lemmatizedWords.append(lemmatized)
# Out:
# Word Token      ---->   Lemmatization
#
#
# telegraph       ---->       telegraph
# calcutta        ---->        calcutta
# business        ---->        business
# rbi             ---->             rbi
# breather        ---->        breather
# urban           ---->           urban
# coop            ---->            coop
# banks           ---->            bank
# special         ---->         special
# correspondent   ---->   correspondent
# mumbai          ---->          mumbai
# sept            ---->            sept
# reserve         ---->         reserve
# bank            ---->            bank
# relaxed         ---->         relaxed
# loan            ---->            loan
# impairment      ---->      impairment
# norms           ---->            norm
# urban           ---->           urban
# cooperative     ---->     cooperative
# banks           ---->            bank
# day             ---->             day
# norm            ---->            norm
# relating        ---->          relate
# asset           ---->           asset
# classification  ---->  classification
# provisioning    ---->       provision
# applicable      ---->      applicable
# gold            ---->            gold
# loans           ---->            loan
# small           ---->           small
# loans           ---->            loan
# rs              ---->               r
# lakh            ---->            lakh
# financial       ---->       financial
# year            ---->            year
# ending          ---->             end
# march           ---->           march
# till            ---->            till
# loans           ---->            loan
# would           ---->           would
# governed        ---->          govern
# day             ---->             day
# impairment      ---->      impairment
# norm            ---->            norm
# earlier         ---->         earlier
# central         ---->         central
# bank            ---->            bank
# advised         ---->          advise
# ucbs            ---->            ucbs
# apply           ---->           apply
# day             ---->             day
# norm            ---->            norm
# financial       ---->       financial
# year            ---->            year
# ending          ---->             end
# march           ---->           march
# decision        ---->        decision
# based           ---->            base
# representations ---->  representation
# ucbs            ---->            ucbs
# reserve         ---->         reserve
# bank            ---->            bank
# release         ---->         release
# said            ---->             say
# today           ---->           today
# rbi             ---->             rbi
# governor        ---->        governor
# v               ---->               v
# reddy           ---->           reddy
# held            ---->            held
# meeting         ---->         meeting
# federations     ---->      federation
# cooperative     ---->     cooperative
# banks           ---->            bank
# september       ---->       september
# ucbs            ---->            ucbs
# sought          ---->          sought
# relaxation      ---->      relaxation
# norms           ---->            norm
# meeting         ---->         meeting
# specific        ---->        specific
# suggestions     ---->      suggestion
# placed          ---->           place
# included        ---->         include
# proposal        ---->        proposal
# modify          ---->          modify
# prudential      ---->      prudential
# regulations     ---->      regulation
# including       ---->         include
# deferring       ---->           defer
# application     ---->     application
# day             ---->             day
# norm            ---->            norm
# plan            ---->            plan
# exclude         ---->         exclude
# gold            ---->            gold
# loans           ---->            loan
# loans           ---->            loan
# rs              ---->               r
# lakh            ---->            lakh
# norms           ---->            norm
# rationalise     ---->     rationalise
# procedures      ---->       procedure
# governing       ---->          govern
# maintenance     ---->     maintenance
# cash            ---->            cash
# reserve         ---->         reserve
# ratio           ---->           ratio
# crr             ---->             crr
# representatives ---->  representative
# also            ---->            also
# requested       ---->         request
# forthcoming     ---->     forthcoming
# basel           ---->           basel
# ii              ---->              ii
# norms           ---->            norm
# applied         ---->           apply
# modified        ---->          modify
# form            ---->            form
# suit            ---->            suit
# localised       ---->        localise
# nature          ---->          nature
# telegraph       ---->       telegraph
# calcutta        ---->        calcutta
# business        ---->        business
# new             ---->             new
# lic             ---->             lic
# pension         ---->         pension
# plans           ---->            plan
# staff           ---->           staff
# reporter        ---->        reporter
# calcutta        ---->        calcutta
# sept            ---->            sept
# life            ---->            life
# insurance       ---->       insurance
# corporation     ---->     corporation
# india           ---->           india
# lic             ---->             lic
# plans           ---->            plan
# unveil          ---->          unveil
# three           ---->           three
# new             ---->             new
# products        ---->         product
# including       ---->         include
# unitlinked      ---->      unitlinked
# pension         ---->         pension
# plan            ---->            plan
# sought          ---->          sought
# approval        ---->        approval
# insurance       ---->       insurance
# regulatory      ---->      regulatory
# development     ---->     development
# authority       ---->       authority
# india           ---->           india
# irda            ---->            irda
# approval        ---->        approval
# three           ---->           three
# policies        ---->          policy
# launch          ---->          launch
# soon            ---->            soon
# receive         ---->         receive
# said            ---->             say
# lic             ---->             lic
# zonal           ---->           zonal
# manager         ---->         manager
# k               ---->               k
# mehrotra        ---->        mehrotra
# apart           ---->           apart
# unitlinked      ---->      unitlinked
# pension         ---->         pension
# plan            ---->            plan
# schemes         ---->          scheme
# would           ---->           would
# include         ---->         include
# childrens       ---->       childrens
# plan            ---->            plan
# another         ---->         another
# similar         ---->         similar
# jeevan          ---->          jeevan
# shree           ---->           shree
# high            ---->            high
# networth        ---->        networth
# individuals     ---->      individual
# mehrotra        ---->        mehrotra
# acknowledged    ---->     acknowledge
# response        ---->        response
# lics            ---->            lics
# existing        ---->           exist
# pension         ---->         pension
# schemes         ---->          scheme
# encouraging     ---->       encourage
# lack            ---->            lack
# awareness       ---->       awareness
# among           ---->           among
# employees       ---->        employee
# rural           ---->           rural
# unorganised     ---->     unorganised
# sector          ---->          sector
# said            ---->             say
# mehrotra        ---->        mehrotra
# however         ---->         however
# company         ---->         company
# planning        ---->        planning
# increase        ---->        increase
# awareness       ---->       awareness
# among           ---->           among
# sections        ---->         section
# people          ---->          people
# number          ---->          number
# programmes      ---->       programme
# addressed       ---->         address
# agents          ---->           agent
# marketing       ---->       marketing
# people          ---->          people
# mehrotra        ---->        mehrotra
# added           ---->             add
# till            ---->            till
# august          ---->          august
# corporation     ---->     corporation
# sold            ---->            sell
# total           ---->           total
# pension         ---->         pension
# policies        ---->          policy
# premium         ---->         premium
# income          ---->          income
# rs              ---->               r
# crore           ---->           crore
# eastern         ---->         eastern
# zone            ---->            zone
# lic             ---->             lic
# sold            ---->            sell
# policies        ---->          policy
# period          ---->          period
# april           ---->           april
# august          ---->          august
# total           ---->           total
# premium         ---->         premium
# income          ---->          income
# rs              ---->               r
# crore           ---->           crore
# financial       ---->       financial
# year            ---->            year
# lic             ---->             lic
# sold            ---->            sell
# total           ---->           total
# lakh            ---->            lakh
# pension         ---->         pension
# policies        ---->          policy
# premium         ---->         premium
# income          ---->          income
# rs              ---->               r
# crore           ---->           crore
# share           ---->           share
# eastern         ---->         eastern
# zone            ---->            zone
# policies        ---->          policy
# rs              ---->               r
# crore           ---->           crore
# premium         ---->         premium
# income          ---->          income
# mehrotra        ---->        mehrotra
# said            ---->             say
# corporation     ---->     corporation
# would           ---->           would
# give            ---->            give
# special         ---->         special
# emphasis        ---->        emphasis
# increasing      ---->        increase
# distribution    ---->    distribution
# channels        ---->         channel
# maintain        ---->        maintain
# market          ---->          market
# share           ---->           share
# also            ---->            also
# increase        ---->        increase
# popularity      ---->      popularity
# pension         ---->         pension
# schemes         ---->          scheme
# lic             ---->             lic
# markets         ---->          market
# products        ---->         product
# outlets         ---->          outlet
# banks           ---->            bank
# namely          ---->          namely
# uco             ---->             uco
# bank            ---->            bank
# corporation     ---->     corporation
# bank            ---->            bank
# allahabad       ---->       allahabad
# bank            ---->            bank
# west            ---->            west
# bengal          ---->          bengal
# state           ---->           state
# cooperative     ---->     cooperative
# bank            ---->            bank
# licensed        ---->         license
# corporate       ---->       corporate
# agents          ---->           agent
# market          ---->          market
# products        ---->         product
# outlets         ---->          outlet
# august          ---->          august
# eastern         ---->         eastern
# zone            ---->            zone
# earned          ---->            earn
# premium         ---->         premium
# income          ---->          income
# rs              ---->               r
# crore           ---->           crore
# selling         ---->            sell
# lakh            ---->            lakh
# policies        ---->          policy
# recording       ---->          record
# growth          ---->          growth
# per             ---->             per
# cent            ---->            cent
# per             ---->             per
# cent            ---->            cent
# premium         ---->         premium
# policies        ---->          policy
# respectively    ---->    respectively
# bima            ---->            bima
# plus            ---->            plus
# fetched         ---->           fetch
# premium         ---->         premium
# rs              ---->               r
# crore           ---->           crore
# seven           ---->           seven
# important       ---->       important
# new             ---->             new
# plans           ---->            plan
# earned          ---->            earn
# premium         ---->         premium
# rs              ---->               r
# crore           ---->           crore
# telegraph       ---->       telegraph
# calcutta        ---->        calcutta
# business        ---->        business
# advisers        ---->         adviser
# help            ---->            help
# wbidc           ---->           wbidc
# sell            ---->            sell
# bad             ---->             bad
# assets          ---->           asset
# sutanuka        ---->        sutanuka
# ghosal          ---->          ghosal
# calcutta        ---->        calcutta
# sept            ---->            sept
# west            ---->            west
# bengal          ---->          bengal
# industrial      ---->      industrial
# development     ---->     development
# corporation     ---->     corporation
# wbidc           ---->           wbidc
# appoint         ---->         appoint
# advisers        ---->         adviser
# help            ---->            help
# dispose         ---->         dispose
# assets          ---->           asset
# liquidation     ---->     liquidation
# decision        ---->        decision
# taken           ---->            take
# corporations    ---->     corporation
# board           ---->           board
# meeting         ---->         meeting
# held            ---->            held
# last            ---->            last
# month           ---->           month
# assets          ---->           asset
# liquidation     ---->     liquidation
# wbidc           ---->           wbidc
# wants           ---->            want
# generate        ---->        generate
# revenues        ---->         revenue
# corporation     ---->     corporation
# soon            ---->            soon
# float           ---->           float
# tender          ---->          tender
# inviting        ---->          invite
# bids            ---->             bid
# advisers        ---->         adviser
# paid            ---->            paid
# commission      ---->      commission
# basis           ---->           basis
# huge            ---->            huge
# assets          ---->           asset
# nonperforming   ---->   nonperforming
# companies       ---->         company
# liquidation     ---->     liquidation
# wbidc           ---->           wbidc
# exposure        ---->        exposure
# companies       ---->         company
# want            ---->            want
# unlock          ---->          unlock
# idle            ---->            idle
# assets          ---->           asset
# enhance         ---->         enhance
# revenue         ---->         revenue
# flow            ---->            flow
# advisers        ---->         adviser
# help            ---->            help
# us              ---->               u
# selling         ---->            sell
# assets          ---->           asset
# corporation     ---->     corporation
# pay             ---->             pay
# good            ---->            good
# commissions     ---->      commission
# said            ---->             say
# senior          ---->          senior
# wbidc           ---->           wbidc
# official        ---->        official
# wbidc           ---->           wbidc
# consciously     ---->     consciously
# decided         ---->          decide
# increase        ---->        increase
# standard        ---->        standard
# assets          ---->           asset
# order           ---->           order
# reduce          ---->          reduce
# net             ---->             net
# nonperforming   ---->   nonperforming
# asset           ---->           asset
# net             ---->             net
# asset           ---->           asset
# ratio           ---->           ratio
# corporation     ---->     corporation
# planning        ---->        planning
# increase        ---->        increase
# exposure        ---->        exposure
# forthcoming     ---->     forthcoming
# projects        ---->         project
# last            ---->            last
# couple          ---->          couple
# years           ---->            year
# wbidc           ---->           wbidc
# invested        ---->          invest
# heavily         ---->         heavily
# last            ---->            last
# major           ---->           major
# rs              ---->               r
# crore           ---->           crore
# ramrupai        ---->        ramrupai
# steel           ---->           steel
# sources         ---->          source
# said            ---->             say
# corporation     ---->     corporation
# may             ---->             may
# increase        ---->        increase
# exposure        ---->        exposure
# rs              ---->               r
# crore           ---->           crore
# certain         ---->         certain
# projects        ---->         project
# present         ---->         present
# three           ---->           three
# steel           ---->           steel
# cement          ---->          cement
# project         ---->         project
# wbidcs          ---->          wbidcs
# platter         ---->         platter
# however         ---->         however
# investment      ---->      investment
# form            ---->            form
# loans           ---->            loan
# wbidc           ---->           wbidc
# invest          ---->          invest
# equity          ---->          equity
# big             ---->             big
# way             ---->             way
# unless          ---->          unless
# big             ---->             big
# project         ---->         project
# wbidc           ---->           wbidc
# pick            ---->            pick
# equity          ---->          equity
# buy             ---->             buy
# per             ---->             per
# cent            ---->            cent
# kulpi           ---->           kulpi
# port            ---->            port
# developed       ---->       developed
# bengal          ---->          bengal
# government      ---->      government
# p               ---->               p
# amp             ---->             amp
# bengal          ---->          bengal
# port            ---->            port
# sources         ---->          source
# added           ---->             add
# corporation     ---->     corporation
# may             ---->             may
# also            ---->            also
# buy             ---->             buy
# stake           ---->           stake
# tatas           ---->           tatas
# coke            ---->            coke
# oven            ---->            oven
# project         ---->         project
# slated          ---->            slat
# come            ---->            come
# haldia          ---->          haldia
# wbidc           ---->           wbidc
# disbursed       ---->        disburse
# rs              ---->               r
# crore           ---->           crore
# loans           ---->            loan
# year            ---->            year
# target          ---->          target
# rs              ---->               r
# crore           ---->           crore
# corporation     ---->     corporation
# also            ---->            also
# trying          ---->             try
# cut             ---->             cut
# bad             ---->             bad
# assets          ---->           asset
# wbidc           ---->           wbidc
# trimmed         ---->            trim
# bad             ---->             bad
# nonperforming   ---->   nonperforming
# assets          ---->           asset
# npas            ---->             npa
# rs              ---->               r
# crore           ---->           crore
# year            ---->            year
# target          ---->          target
# rs              ---->               r
# crore           ---->           crore
# wbidc           ---->           wbidc
# decided         ---->          decide
# raise           ---->           raise
# money           ---->           money
# receivables     ---->     receivables
# part            ---->            part
# securitisation  ---->  securitisation
# exercise        ---->        exercise
# icici           ---->           icici
# bank            ---->            bank
# agreed          ---->           agree
# provide         ---->         provide
# rs              ---->               r
# crore           ---->           crore
# loan            ---->            loan
# receivables     ---->     receivables
# coupon          ---->          coupon
# rate            ---->            rate
# per             ---->             per
# cent            ---->            cent
# corporation     ---->     corporation
# lend            ---->            lend
# money           ---->           money
# higher          ---->            high
# interest        ---->        interest
# per             ---->             per
# cent            ---->            cent
# thereby         ---->         thereby
# augmenting      ---->         augment
# revenue         ---->         revenue
# state           ---->           state
# bank            ---->            bank
# india           ---->           india
# well            ---->            well
# uti             ---->             uti
# bank            ---->            bank
# keen            ---->            keen
# provide         ---->         provide
# loans           ---->            loan
# receivables     ---->     receivables
# interest        ---->        interest
# per             ---->             per
# cent            ---->            cent
# idbi            ---->            idbi
# also            ---->            also
# keen            ---->            keen
# provide         ---->         provide
# us              ---->               u
# loans           ---->            loan
# much            ---->            much
# lower           ---->             low
# interest        ---->        interest
# per             ---->             per
# cent            ---->            cent
# talks           ---->            talk
# sources         ---->          source
# added           ---->             add
# telegraph       ---->       telegraph
# calcutta        ---->        calcutta
# business        ---->        business
# eyes            ---->             eye
# greenspan       ---->       greenspan
# week            ---->            week
# greenspan       ---->       greenspan
# focus           ---->           focus
# london          ---->          london
# sept            ---->            sept
# reuters         ---->         reuters
# federal         ---->         federal
# reserve         ---->         reserve
# chairman        ---->        chairman
# alan            ---->            alan
# greenspans      ---->      greenspans
# testimony       ---->       testimony
# capitol         ---->         capitol
# hill            ---->            hill
# midweek         ---->         midweek
# main            ---->            main
# draw            ---->            draw
# global          ---->          global
# financial       ---->       financial
# markets         ---->          market
# week            ---->            week
# absence         ---->         absence
# significant     ---->     significant
# data            ---->            data
# either          ---->          either
# side            ---->            side
# atlantic        ---->        atlantic
# analysts        ---->         analyst
# said            ---->             say
# ruthlessly      ---->      ruthlessly
# put             ---->             put
# green           ---->           green
# spans           ---->            span
# testimony       ---->       testimony
# real            ---->            real
# factor          ---->          factor
# matters         ---->          matter
# next            ---->            next
# week            ---->            week
# global          ---->          global
# foreign         ---->         foreign
# exchange        ---->        exchange
# debt            ---->            debt
# markets         ---->          market
# said            ---->             say
# smith           ---->           smith
# economist       ---->       economist
# icap            ---->            icap
# london          ---->          london
# greenspan       ---->       greenspan
# speak           ---->           speak
# house           ---->           house
# representatives ---->  representative
# budget          ---->          budget
# committee       ---->       committee
# next            ---->            next
# wednesday       ---->       wednesday
# us              ---->               u
# august          ---->          august
# nonfarm         ---->         nonfarm
# payrolls        ---->         payroll
# report          ---->          report
# friday          ---->          friday
# preserved       ---->        preserve
# prospect        ---->        prospect
# rising          ---->            rise
# federal         ---->         federal
# funds           ---->            fund
# rate            ---->            rate
# analysts        ---->         analyst
# said            ---->             say
# would           ---->           would
# lend            ---->            lend
# support         ---->         support
# central         ---->         central
# bankers         ---->          banker
# outlook         ---->         outlook
# worlds          ---->           world
# biggest         ---->             big
# economy         ---->         economy
# although        ---->        although
# employers       ---->        employer
# added           ---->             add
# payrolls        ---->         payroll
# august          ---->          august
# median          ---->          median
# forecast        ---->        forecast
# upward          ---->          upward
# revisions       ---->        revision
# june            ---->            june
# july            ---->            july
# data            ---->            data
# debt            ---->            debt
# markets         ---->          market
# dived           ---->            dive
# figures         ---->          figure
# nonfarm         ---->         nonfarm
# payrolls        ---->         payroll
# dont            ---->            dont
# change          ---->          change
# anything        ---->        anything
# provide         ---->         provide
# greenspan       ---->       greenspan
# ammunition      ---->      ammunition
# say             ---->             say
# economy         ---->         economy
# rebounding      ---->         rebound
# leave           ---->           leave
# scope           ---->           scope
# tightening      ---->         tighten
# rates           ---->            rate
# said            ---->             say
# marc            ---->            marc
# ostwald         ---->         ostwald
# bond            ---->            bond
# broker          ---->          broker
# monument        ---->        monument
# securities      ---->        security
# london          ---->          london
# us              ---->               u
# rates           ---->            rate
# last            ---->            last
# hiked           ---->            hike
# basis           ---->           basis
# points          ---->           point
# per             ---->             per
# cent            ---->            cent
# august          ---->          august
# midyear         ---->         midyear
# nestled         ---->          nestle
# per             ---->             per
# cent            ---->            cent
# year            ---->            year
# lowest          ---->             low
# since           ---->           since
# mids            ---->            mids
# greenspan       ---->       greenspan
# say             ---->             say
# tightening      ---->         tighten
# necessary       ---->       necessary
# remove          ---->          remove
# unnecessary     ---->     unnecessary
# accommodation   ---->   accommodation
# given           ---->            give
# market          ---->          market
# resulted        ---->          result
# negative        ---->        negative
# real            ---->            real
# interest        ---->        interest
# rates           ---->            rate
# added           ---->             add
# since           ---->           since
# testimony       ---->       testimony
# july            ---->            july
# noted           ---->            note
# payrolls        ---->         payroll
# averaged        ---->         average
# per             ---->             per
# month           ---->           month
# past            ---->            past
# six             ---->             six
# months          ---->           month
# average         ---->         average
# reading         ---->         reading
# slowed          ---->            slow
# three           ---->           three
# months          ---->           month
# july            ---->            july
# said            ---->             say
# research        ---->        research
# note            ---->            note
# friday          ---->          friday
# hsbc            ---->            hsbc
# bank            ---->            bank
# greenspan       ---->       greenspan
# likely          ---->          likely
# blame           ---->           blame
# recent          ---->          recent
# disappointment  ---->  disappointment
# high            ---->            high
# oil             ---->             oil
# price           ---->           price
# recent          ---->          recent
# pullback        ---->        pullback
# energy          ---->          energy
# prices          ---->           price
# could           ---->           could
# give            ---->            give
# breathing       ---->       breathing
# roomto          ---->          roomto
# remain          ---->          remain
# growth          ---->          growth
# bullish         ---->         bullish
# note            ---->            note
# added           ---->             add
# telegraph       ---->       telegraph
# calcutta        ---->        calcutta
# business        ---->        business
# rbi             ---->             rbi
# fuels           ---->            fuel
# rally           ---->           rally
# bank            ---->            bank
# stocks          ---->           stock
# special         ---->         special
# correspondent   ---->   correspondent
# mumbai          ---->          mumbai
# sept            ---->            sept
# bank            ---->            bank
# shares          ---->           share
# rallied         ---->           rally
# stock           ---->           stock
# exchanges       ---->        exchange
# today           ---->           today
# reserve         ---->         reserve
# bank            ---->            bank
# india           ---->           india
# relaxed         ---->         relaxed
# limits          ---->           limit
# banks           ---->            bank
# bond            ---->            bond
# investments     ---->      investment
# yesterday       ---->       yesterday
# rbi             ---->             rbi
# move            ---->            move
# expected        ---->          expect
# positive        ---->        positive
# impact          ---->          impact
# balancesheet    ---->    balancesheet
# public          ---->          public
# sector          ---->          sector
# banks           ---->            bank
# would           ---->           would
# cushion         ---->         cushion
# falling         ---->            fall
# government      ---->      government
# security        ---->        security
# prices          ---->           price
# rbi             ---->             rbi
# allowed         ---->           allow
# banks           ---->            bank
# exceed          ---->          exceed
# per             ---->             per
# cent            ---->            cent
# limit           ---->           limit
# investments     ---->      investment
# heldtomaturity  ---->  heldtomaturity
# htm             ---->             htm
# category        ---->        category
# provided        ---->         provide
# excess          ---->          excess
# comprises       ---->       comprises
# statutory       ---->       statutory
# liquidity       ---->       liquidity
# ratio           ---->           ratio
# slr             ---->             slr
# securities      ---->        security
# central         ---->         central
# bank            ---->            bank
# also            ---->            also
# stipulated      ---->       stipulate
# total           ---->           total
# slr             ---->             slr
# securities      ---->        security
# held            ---->            held
# htm             ---->             htm
# category        ---->        category
# per             ---->             per
# cent            ---->            cent
# demand          ---->          demand
# time            ---->            time
# liabilities     ---->       liability
# dtl             ---->             dtl
# last            ---->            last
# friday          ---->          friday
# second          ---->          second
# preceding       ---->         precede
# fortnight       ---->       fortnight
# according       ---->          accord
# analysts        ---->         analyst
# rbi             ---->             rbi
# move            ---->            move
# protect         ---->         protect
# balancesheets   ---->   balancesheets
# nationalised    ---->     nationalise
# banks           ---->            bank
# impact          ---->          impact
# falling         ---->            fall
# government      ---->      government
# security        ---->        security
# prices          ---->           price
# nationalised    ---->     nationalise
# banks           ---->            bank
# heavy           ---->           heavy
# investors       ---->        investor
# government      ---->      government
# securities      ---->        security
# investments     ---->      investment
# exceed          ---->          exceed
# minimum         ---->         minimum
# level           ---->           level
# per             ---->             per
# cent            ---->            cent
# deposits        ---->         deposit
# presently       ---->       presently
# three           ---->           three
# categories      ---->        category
# banks           ---->            bank
# hold            ---->            hold
# securities      ---->        security
# include         ---->         include
# htm             ---->             htm
# availableforsale ----> availableforsale
# heldfortrading  ---->  heldfortrading
# categories      ---->        category
# rbi             ---->             rbi
# regulations     ---->      regulation
# stipulate       ---->       stipulate
# banks           ---->            bank
# must            ---->            must
# mark            ---->            mark
# market          ---->          market
# holdings        ---->         holding
# availableforsale ----> availableforsale
# heldfortrading  ---->  heldfortrading
# categories      ---->        category
# market          ---->          market
# circles         ---->          circle
# said            ---->             say
# bank            ---->            bank
# stocks          ---->           stock
# pressure        ---->        pressure
# recent          ---->          recent
# past            ---->            past
# concerns        ---->         concern
# impact          ---->          impact
# likely          ---->          likely
# rise            ---->            rise
# interest        ---->        interest
# rates           ---->            rate
# witnessed       ---->         witness
# brisk           ---->           brisk
# buying          ---->          buying
# investors       ---->        investor
# chasing         ---->           chase
# nationalised    ---->     nationalise
# banks           ---->            bank
# bse             ---->             bse
# state           ---->           state
# bank            ---->            bank
# india           ---->           india
# sbi             ---->             sbi
# actively        ---->        actively
# traded          ---->           trade
# counter         ---->         counter
# highest         ---->            high
# turnover        ---->        turnover
# rs              ---->               r
# crore           ---->           crore
# sbi             ---->             sbi
# scrip           ---->           scrip
# firmed          ---->            firm
# rs              ---->               r
# rs              ---->               r
# bank            ---->            bank
# baroda          ---->          baroda
# also            ---->            also
# gained          ---->            gain
# rs              ---->               r
# finish          ---->          finish
# rs              ---->               r
# corporation     ---->     corporation
# bank            ---->            bank
# shares          ---->           share
# rs              ---->               r
# end             ---->             end
# rs              ---->               r
# canara          ---->          canara
# bank            ---->            bank
# gained          ---->            gain
# rs              ---->               r
# finish          ---->          finish
# rs              ---->               r
# bse             ---->             bse
# bankex          ---->          bankex
# one             ---->             one
# leading         ---->            lead
# indices         ---->           index
# exchange        ---->        exchange
# gained          ---->            gain
# around          ---->          around
# points          ---->           point
# opening         ---->         opening
# shot            ---->            shot
# days            ---->             day
# high            ---->            high
# closing         ---->         closing
# rbis            ---->             rbi
# decision        ---->        decision
# raise           ---->           raise
# investment      ---->      investment
# limits          ---->           limit
# come            ---->            come
# time            ---->            time
# banks           ---->            bank
# witnessed       ---->         witness
# trading         ---->         trading
# gains           ---->            gain
# evaporate       ---->       evaporate
# first           ---->           first
# quarter         ---->         quarter
# current         ---->         current
# fiscal          ---->          fiscal
# due             ---->             due
# sustained       ---->         sustain
# drop            ---->            drop
# prices          ---->           price
# government      ---->      government
# securities      ---->        security
# treasury        ---->        treasury
# circles         ---->          circle
# feel            ---->            feel
# central         ---->         central
# bank            ---->            bank
# preparing       ---->         prepare
# banking         ---->         banking
# sector          ---->          sector
# interest        ---->        interest
# rate            ---->            rate
# hike            ---->            hike
# months          ---->           month
# come            ---->            come
# far             ---->             far
# rbi             ---->             rbi
# desisted        ---->          desist
# raising         ---->           raise
# key             ---->             key
# rates           ---->            rate
# benchmark       ---->       benchmark
# bank            ---->            bank
# rate            ---->            rate
# still           ---->           still
# three           ---->           three
# decade          ---->          decade
# low             ---->             low

# %% [markdown]
# ## Showing differences between Stemming and Lemmatization on the text:
# The output will show the result of performing **stemming** and **lemmatization** on each of the word tokens.<br>
# It is thus observed that for the current assignment **_lemmatization_** proves to be better at transforming the surface word tokens to their roots.

# %%
print("Stemmed".ljust(18), "<---->", "Lemmatized".rjust(18))
print("\n")
for stemmed, lemmatized in zip(stemmedWords, lemmatizedWords):
  print(stemmed.ljust(18), "<---->", lemmatized.rjust(18))
# Out:
# Stemmed            <---->         Lemmatized
#
#
# telegraph          <---->          telegraph
# calcutta           <---->           calcutta
# busi               <---->           business
# rbi                <---->                rbi
# breather           <---->           breather
# urban              <---->              urban
# coop               <---->               coop
# bank               <---->               bank
# special            <---->            special
# correspond         <---->      correspondent
# mumbai             <---->             mumbai
# sept               <---->               sept
# reserv             <---->            reserve
# bank               <---->               bank
# relax              <---->            relaxed
# loan               <---->               loan
# impair             <---->         impairment
# norm               <---->               norm
# urban              <---->              urban
# cooper             <---->        cooperative
# bank               <---->               bank
# day                <---->                day
# norm               <---->               norm
# relat              <---->             relate
# asset              <---->              asset
# classif            <---->     classification
# provis             <---->          provision
# applic             <---->         applicable
# gold               <---->               gold
# loan               <---->               loan
# small              <---->              small
# loan               <---->               loan
# rs                 <---->                  r
# lakh               <---->               lakh
# financi            <---->          financial
# year               <---->               year
# end                <---->                end
# march              <---->              march
# till               <---->               till
# loan               <---->               loan
# would              <---->              would
# govern             <---->             govern
# day                <---->                day
# impair             <---->         impairment
# norm               <---->               norm
# earlier            <---->            earlier
# central            <---->            central
# bank               <---->               bank
# advis              <---->             advise
# ucb                <---->               ucbs
# appli              <---->              apply
# day                <---->                day
# norm               <---->               norm
# financi            <---->          financial
# year               <---->               year
# end                <---->                end
# march              <---->              march
# decis              <---->           decision
# base               <---->               base
# represent          <---->     representation
# ucb                <---->               ucbs
# reserv             <---->            reserve
# bank               <---->               bank
# releas             <---->            release
# said               <---->                say
# today              <---->              today
# rbi                <---->                rbi
# governor           <---->           governor
# v                  <---->                  v
# reddi              <---->              reddy
# held               <---->               held
# meet               <---->            meeting
# feder              <---->         federation
# cooper             <---->        cooperative
# bank               <---->               bank
# septemb            <---->          september
# ucb                <---->               ucbs
# sought             <---->             sought
# relax              <---->         relaxation
# norm               <---->               norm
# meet               <---->            meeting
# specif             <---->           specific
# suggest            <---->         suggestion
# place              <---->              place
# includ             <---->            include
# propos             <---->           proposal
# modifi             <---->             modify
# prudenti           <---->         prudential
# regul              <---->         regulation
# includ             <---->            include
# defer              <---->              defer
# applic             <---->        application
# day                <---->                day
# norm               <---->               norm
# plan               <---->               plan
# exclud             <---->            exclude
# gold               <---->               gold
# loan               <---->               loan
# loan               <---->               loan
# rs                 <---->                  r
# lakh               <---->               lakh
# norm               <---->               norm
# rationalis         <---->        rationalise
# procedur           <---->          procedure
# govern             <---->             govern
# mainten            <---->        maintenance
# cash               <---->               cash
# reserv             <---->            reserve
# ratio              <---->              ratio
# crr                <---->                crr
# repres             <---->     representative
# also               <---->               also
# request            <---->            request
# forthcom           <---->        forthcoming
# basel              <---->              basel
# ii                 <---->                 ii
# norm               <---->               norm
# appli              <---->              apply
# modifi             <---->             modify
# form               <---->               form
# suit               <---->               suit
# localis            <---->           localise
# natur              <---->             nature
# telegraph          <---->          telegraph
# calcutta           <---->           calcutta
# busi               <---->           business
# new                <---->                new
# lic                <---->                lic
# pension            <---->            pension
# plan               <---->               plan
# staff              <---->              staff
# report             <---->           reporter
# calcutta           <---->           calcutta
# sept               <---->               sept
# life               <---->               life
# insur              <---->          insurance
# corpor             <---->        corporation
# india              <---->              india
# lic                <---->                lic
# plan               <---->               plan
# unveil             <---->             unveil
# three              <---->              three
# new                <---->                new
# product            <---->            product
# includ             <---->            include
# unitlink           <---->         unitlinked
# pension            <---->            pension
# plan               <---->               plan
# sought             <---->             sought
# approv             <---->           approval
# insur              <---->          insurance
# regulatori         <---->         regulatory
# develop            <---->        development
# author             <---->          authority
# india              <---->              india
# irda               <---->               irda
# approv             <---->           approval
# three              <---->              three
# polici             <---->             policy
# launch             <---->             launch
# soon               <---->               soon
# receiv             <---->            receive
# said               <---->                say
# lic                <---->                lic
# zonal              <---->              zonal
# manag              <---->            manager
# k                  <---->                  k
# mehrotra           <---->           mehrotra
# apart              <---->              apart
# unitlink           <---->         unitlinked
# pension            <---->            pension
# plan               <---->               plan
# scheme             <---->             scheme
# would              <---->              would
# includ             <---->            include
# children           <---->          childrens
# plan               <---->               plan
# anoth              <---->            another
# similar            <---->            similar
# jeevan             <---->             jeevan
# shree              <---->              shree
# high               <---->               high
# networth           <---->           networth
# individu           <---->         individual
# mehrotra           <---->           mehrotra
# acknowledg         <---->        acknowledge
# respons            <---->           response
# lic                <---->               lics
# exist              <---->              exist
# pension            <---->            pension
# scheme             <---->             scheme
# encourag           <---->          encourage
# lack               <---->               lack
# awar               <---->          awareness
# among              <---->              among
# employe            <---->           employee
# rural              <---->              rural
# unorganis          <---->        unorganised
# sector             <---->             sector
# said               <---->                say
# mehrotra           <---->           mehrotra
# howev              <---->            however
# compani            <---->            company
# plan               <---->           planning
# increas            <---->           increase
# awar               <---->          awareness
# among              <---->              among
# section            <---->            section
# peopl              <---->             people
# number             <---->             number
# programm           <---->          programme
# address            <---->            address
# agent              <---->              agent
# market             <---->          marketing
# peopl              <---->             people
# mehrotra           <---->           mehrotra
# ad                 <---->                add
# till               <---->               till
# august             <---->             august
# corpor             <---->        corporation
# sold               <---->               sell
# total              <---->              total
# pension            <---->            pension
# polici             <---->             policy
# premium            <---->            premium
# incom              <---->             income
# rs                 <---->                  r
# crore              <---->              crore
# eastern            <---->            eastern
# zone               <---->               zone
# lic                <---->                lic
# sold               <---->               sell
# polici             <---->             policy
# period             <---->             period
# april              <---->              april
# august             <---->             august
# total              <---->              total
# premium            <---->            premium
# incom              <---->             income
# rs                 <---->                  r
# crore              <---->              crore
# financi            <---->          financial
# year               <---->               year
# lic                <---->                lic
# sold               <---->               sell
# total              <---->              total
# lakh               <---->               lakh
# pension            <---->            pension
# polici             <---->             policy
# premium            <---->            premium
# incom              <---->             income
# rs                 <---->                  r
# crore              <---->              crore
# share              <---->              share
# eastern            <---->            eastern
# zone               <---->               zone
# polici             <---->             policy
# rs                 <---->                  r
# crore              <---->              crore
# premium            <---->            premium
# incom              <---->             income
# mehrotra           <---->           mehrotra
# said               <---->                say
# corpor             <---->        corporation
# would              <---->              would
# give               <---->               give
# special            <---->            special
# emphasi            <---->           emphasis
# increas            <---->           increase
# distribut          <---->       distribution
# channel            <---->            channel
# maintain           <---->           maintain
# market             <---->             market
# share              <---->              share
# also               <---->               also
# increas            <---->           increase
# popular            <---->         popularity
# pension            <---->            pension
# scheme             <---->             scheme
# lic                <---->                lic
# market             <---->             market
# product            <---->            product
# outlet             <---->             outlet
# bank               <---->               bank
# name               <---->             namely
# uco                <---->                uco
# bank               <---->               bank
# corpor             <---->        corporation
# bank               <---->               bank
# allahabad          <---->          allahabad
# bank               <---->               bank
# west               <---->               west
# bengal             <---->             bengal
# state              <---->              state
# cooper             <---->        cooperative
# bank               <---->               bank
# licens             <---->            license
# corpor             <---->          corporate
# agent              <---->              agent
# market             <---->             market
# product            <---->            product
# outlet             <---->             outlet
# august             <---->             august
# eastern            <---->            eastern
# zone               <---->               zone
# earn               <---->               earn
# premium            <---->            premium
# incom              <---->             income
# rs                 <---->                  r
# crore              <---->              crore
# sell               <---->               sell
# lakh               <---->               lakh
# polici             <---->             policy
# record             <---->             record
# growth             <---->             growth
# per                <---->                per
# cent               <---->               cent
# per                <---->                per
# cent               <---->               cent
# premium            <---->            premium
# polici             <---->             policy
# respect            <---->       respectively
# bima               <---->               bima
# plu                <---->               plus
# fetch              <---->              fetch
# premium            <---->            premium
# rs                 <---->                  r
# crore              <---->              crore
# seven              <---->              seven
# import             <---->          important
# new                <---->                new
# plan               <---->               plan
# earn               <---->               earn
# premium            <---->            premium
# rs                 <---->                  r
# crore              <---->              crore
# telegraph          <---->          telegraph
# calcutta           <---->           calcutta
# busi               <---->           business
# advis              <---->            adviser
# help               <---->               help
# wbidc              <---->              wbidc
# sell               <---->               sell
# bad                <---->                bad
# asset              <---->              asset
# sutanuka           <---->           sutanuka
# ghosal             <---->             ghosal
# calcutta           <---->           calcutta
# sept               <---->               sept
# west               <---->               west
# bengal             <---->             bengal
# industri           <---->         industrial
# develop            <---->        development
# corpor             <---->        corporation
# wbidc              <---->              wbidc
# appoint            <---->            appoint
# advis              <---->            adviser
# help               <---->               help
# dispos             <---->            dispose
# asset              <---->              asset
# liquid             <---->        liquidation
# decis              <---->           decision
# taken              <---->               take
# corpor             <---->        corporation
# board              <---->              board
# meet               <---->            meeting
# held               <---->               held
# last               <---->               last
# month              <---->              month
# asset              <---->              asset
# liquid             <---->        liquidation
# wbidc              <---->              wbidc
# want               <---->               want
# gener              <---->           generate
# revenu             <---->            revenue
# corpor             <---->        corporation
# soon               <---->               soon
# float              <---->              float
# tender             <---->             tender
# invit              <---->             invite
# bid                <---->                bid
# advis              <---->            adviser
# paid               <---->               paid
# commiss            <---->         commission
# basi               <---->              basis
# huge               <---->               huge
# asset              <---->              asset
# nonperform         <---->      nonperforming
# compani            <---->            company
# liquid             <---->        liquidation
# wbidc              <---->              wbidc
# exposur            <---->           exposure
# compani            <---->            company
# want               <---->               want
# unlock             <---->             unlock
# idl                <---->               idle
# asset              <---->              asset
# enhanc             <---->            enhance
# revenu             <---->            revenue
# flow               <---->               flow
# advis              <---->            adviser
# help               <---->               help
# us                 <---->                  u
# sell               <---->               sell
# asset              <---->              asset
# corpor             <---->        corporation
# pay                <---->                pay
# good               <---->               good
# commiss            <---->         commission
# said               <---->                say
# senior             <---->             senior
# wbidc              <---->              wbidc
# offici             <---->           official
# wbidc              <---->              wbidc
# conscious          <---->        consciously
# decid              <---->             decide
# increas            <---->           increase
# standard           <---->           standard
# asset              <---->              asset
# order              <---->              order
# reduc              <---->             reduce
# net                <---->                net
# nonperform         <---->      nonperforming
# asset              <---->              asset
# net                <---->                net
# asset              <---->              asset
# ratio              <---->              ratio
# corpor             <---->        corporation
# plan               <---->           planning
# increas            <---->           increase
# exposur            <---->           exposure
# forthcom           <---->        forthcoming
# project            <---->            project
# last               <---->               last
# coupl              <---->             couple
# year               <---->               year
# wbidc              <---->              wbidc
# invest             <---->             invest
# heavili            <---->            heavily
# last               <---->               last
# major              <---->              major
# rs                 <---->                  r
# crore              <---->              crore
# ramrupai           <---->           ramrupai
# steel              <---->              steel
# sourc              <---->             source
# said               <---->                say
# corpor             <---->        corporation
# may                <---->                may
# increas            <---->           increase
# exposur            <---->           exposure
# rs                 <---->                  r
# crore              <---->              crore
# certain            <---->            certain
# project            <---->            project
# present            <---->            present
# three              <---->              three
# steel              <---->              steel
# cement             <---->             cement
# project            <---->            project
# wbidc              <---->             wbidcs
# platter            <---->            platter
# howev              <---->            however
# invest             <---->         investment
# form               <---->               form
# loan               <---->               loan
# wbidc              <---->              wbidc
# invest             <---->             invest
# equiti             <---->             equity
# big                <---->                big
# way                <---->                way
# unless             <---->             unless
# big                <---->                big
# project            <---->            project
# wbidc              <---->              wbidc
# pick               <---->               pick
# equiti             <---->             equity
# buy                <---->                buy
# per                <---->                per
# cent               <---->               cent
# kulpi              <---->              kulpi
# port               <---->               port
# develop            <---->          developed
# bengal             <---->             bengal
# govern             <---->         government
# p                  <---->                  p
# amp                <---->                amp
# bengal             <---->             bengal
# port               <---->               port
# sourc              <---->             source
# ad                 <---->                add
# corpor             <---->        corporation
# may                <---->                may
# also               <---->               also
# buy                <---->                buy
# stake              <---->              stake
# tata               <---->              tatas
# coke               <---->               coke
# oven               <---->               oven
# project            <---->            project
# slate              <---->               slat
# come               <---->               come
# haldia             <---->             haldia
# wbidc              <---->              wbidc
# disburs            <---->           disburse
# rs                 <---->                  r
# crore              <---->              crore
# loan               <---->               loan
# year               <---->               year
# target             <---->             target
# rs                 <---->                  r
# crore              <---->              crore
# corpor             <---->        corporation
# also               <---->               also
# tri                <---->                try
# cut                <---->                cut
# bad                <---->                bad
# asset              <---->              asset
# wbidc              <---->              wbidc
# trim               <---->               trim
# bad                <---->                bad
# nonperform         <---->      nonperforming
# asset              <---->              asset
# npa                <---->                npa
# rs                 <---->                  r
# crore              <---->              crore
# year               <---->               year
# target             <---->             target
# rs                 <---->                  r
# crore              <---->              crore
# wbidc              <---->              wbidc
# decid              <---->             decide
# rais               <---->              raise
# money              <---->              money
# receiv             <---->        receivables
# part               <---->               part
# securitis          <---->     securitisation
# exercis            <---->           exercise
# icici              <---->              icici
# bank               <---->               bank
# agre               <---->              agree
# provid             <---->            provide
# rs                 <---->                  r
# crore              <---->              crore
# loan               <---->               loan
# receiv             <---->        receivables
# coupon             <---->             coupon
# rate               <---->               rate
# per                <---->                per
# cent               <---->               cent
# corpor             <---->        corporation
# lend               <---->               lend
# money              <---->              money
# higher             <---->               high
# interest           <---->           interest
# per                <---->                per
# cent               <---->               cent
# therebi            <---->            thereby
# augment            <---->            augment
# revenu             <---->            revenue
# state              <---->              state
# bank               <---->               bank
# india              <---->              india
# well               <---->               well
# uti                <---->                uti
# bank               <---->               bank
# keen               <---->               keen
# provid             <---->            provide
# loan               <---->               loan
# receiv             <---->        receivables
# interest           <---->           interest
# per                <---->                per
# cent               <---->               cent
# idbi               <---->               idbi
# also               <---->               also
# keen               <---->               keen
# provid             <---->            provide
# us                 <---->                  u
# loan               <---->               loan
# much               <---->               much
# lower              <---->                low
# interest           <---->           interest
# per                <---->                per
# cent               <---->               cent
# talk               <---->               talk
# sourc              <---->             source
# ad                 <---->                add
# telegraph          <---->          telegraph
# calcutta           <---->           calcutta
# busi               <---->           business
# eye                <---->                eye
# greenspan          <---->          greenspan
# week               <---->               week
# greenspan          <---->          greenspan
# focu               <---->              focus
# london             <---->             london
# sept               <---->               sept
# reuter             <---->            reuters
# feder              <---->            federal
# reserv             <---->            reserve
# chairman           <---->           chairman
# alan               <---->               alan
# greenspan          <---->         greenspans
# testimoni          <---->          testimony
# capitol            <---->            capitol
# hill               <---->               hill
# midweek            <---->            midweek
# main               <---->               main
# draw               <---->               draw
# global             <---->             global
# financi            <---->          financial
# market             <---->             market
# week               <---->               week
# absenc             <---->            absence
# signific           <---->        significant
# data               <---->               data
# either             <---->             either
# side               <---->               side
# atlant             <---->           atlantic
# analyst            <---->            analyst
# said               <---->                say
# ruthlessli         <---->         ruthlessly
# put                <---->                put
# green              <---->              green
# span               <---->               span
# testimoni          <---->          testimony
# real               <---->               real
# factor             <---->             factor
# matter             <---->             matter
# next               <---->               next
# week               <---->               week
# global             <---->             global
# foreign            <---->            foreign
# exchang            <---->           exchange
# debt               <---->               debt
# market             <---->             market
# said               <---->                say
# smith              <---->              smith
# economist          <---->          economist
# icap               <---->               icap
# london             <---->             london
# greenspan          <---->          greenspan
# speak              <---->              speak
# hous               <---->              house
# repres             <---->     representative
# budget             <---->             budget
# committe           <---->          committee
# next               <---->               next
# wednesday          <---->          wednesday
# us                 <---->                  u
# august             <---->             august
# nonfarm            <---->            nonfarm
# payrol             <---->            payroll
# report             <---->             report
# friday             <---->             friday
# preserv            <---->           preserve
# prospect           <---->           prospect
# rise               <---->               rise
# feder              <---->            federal
# fund               <---->               fund
# rate               <---->               rate
# analyst            <---->            analyst
# said               <---->                say
# would              <---->              would
# lend               <---->               lend
# support            <---->            support
# central            <---->            central
# banker             <---->             banker
# outlook            <---->            outlook
# world              <---->              world
# biggest            <---->                big
# economi            <---->            economy
# although           <---->           although
# employ             <---->           employer
# ad                 <---->                add
# payrol             <---->            payroll
# august             <---->             august
# median             <---->             median
# forecast           <---->           forecast
# upward             <---->             upward
# revis              <---->           revision
# june               <---->               june
# juli               <---->               july
# data               <---->               data
# debt               <---->               debt
# market             <---->             market
# dive               <---->               dive
# figur              <---->             figure
# nonfarm            <---->            nonfarm
# payrol             <---->            payroll
# dont               <---->               dont
# chang              <---->             change
# anyth              <---->           anything
# provid             <---->            provide
# greenspan          <---->          greenspan
# ammunit            <---->         ammunition
# say                <---->                say
# economi            <---->            economy
# rebound            <---->            rebound
# leav               <---->              leave
# scope              <---->              scope
# tighten            <---->            tighten
# rate               <---->               rate
# said               <---->                say
# marc               <---->               marc
# ostwald            <---->            ostwald
# bond               <---->               bond
# broker             <---->             broker
# monument           <---->           monument
# secur              <---->           security
# london             <---->             london
# us                 <---->                  u
# rate               <---->               rate
# last               <---->               last
# hike               <---->               hike
# basi               <---->              basis
# point              <---->              point
# per                <---->                per
# cent               <---->               cent
# august             <---->             august
# midyear            <---->            midyear
# nestl              <---->             nestle
# per                <---->                per
# cent               <---->               cent
# year               <---->               year
# lowest             <---->                low
# sinc               <---->              since
# mid                <---->               mids
# greenspan          <---->          greenspan
# say                <---->                say
# tighten            <---->            tighten
# necessari          <---->          necessary
# remov              <---->             remove
# unnecessari        <---->        unnecessary
# accommod           <---->      accommodation
# given              <---->               give
# market             <---->             market
# result             <---->             result
# neg                <---->           negative
# real               <---->               real
# interest           <---->           interest
# rate               <---->               rate
# ad                 <---->                add
# sinc               <---->              since
# testimoni          <---->          testimony
# juli               <---->               july
# note               <---->               note
# payrol             <---->            payroll
# averag             <---->            average
# per                <---->                per
# month              <---->              month
# past               <---->               past
# six                <---->                six
# month              <---->              month
# averag             <---->            average
# read               <---->            reading
# slow               <---->               slow
# three              <---->              three
# month              <---->              month
# juli               <---->               july
# said               <---->                say
# research           <---->           research
# note               <---->               note
# friday             <---->             friday
# hsbc               <---->               hsbc
# bank               <---->               bank
# greenspan          <---->          greenspan
# like               <---->             likely
# blame              <---->              blame
# recent             <---->             recent
# disappoint         <---->     disappointment
# high               <---->               high
# oil                <---->                oil
# price              <---->              price
# recent             <---->             recent
# pullback           <---->           pullback
# energi             <---->             energy
# price              <---->              price
# could              <---->              could
# give               <---->               give
# breath             <---->          breathing
# roomto             <---->             roomto
# remain             <---->             remain
# growth             <---->             growth
# bullish            <---->            bullish
# note               <---->               note
# ad                 <---->                add
# telegraph          <---->          telegraph
# calcutta           <---->           calcutta
# busi               <---->           business
# rbi                <---->                rbi
# fuel               <---->               fuel
# ralli              <---->              rally
# bank               <---->               bank
# stock              <---->              stock
# special            <---->            special
# correspond         <---->      correspondent
# mumbai             <---->             mumbai
# sept               <---->               sept
# bank               <---->               bank
# share              <---->              share
# ralli              <---->              rally
# stock              <---->              stock
# exchang            <---->           exchange
# today              <---->              today
# reserv             <---->            reserve
# bank               <---->               bank
# india              <---->              india
# relax              <---->            relaxed
# limit              <---->              limit
# bank               <---->               bank
# bond               <---->               bond
# invest             <---->         investment
# yesterday          <---->          yesterday
# rbi                <---->                rbi
# move               <---->               move
# expect             <---->             expect
# posit              <---->           positive
# impact             <---->             impact
# balancesheet       <---->       balancesheet
# public             <---->             public
# sector             <---->             sector
# bank               <---->               bank
# would              <---->              would
# cushion            <---->            cushion
# fall               <---->               fall
# govern             <---->         government
# secur              <---->           security
# price              <---->              price
# rbi                <---->                rbi
# allow              <---->              allow
# bank               <---->               bank
# exceed             <---->             exceed
# per                <---->                per
# cent               <---->               cent
# limit              <---->              limit
# invest             <---->         investment
# heldtomatur        <---->     heldtomaturity
# htm                <---->                htm
# categori           <---->           category
# provid             <---->            provide
# excess             <---->             excess
# compris            <---->          comprises
# statutori          <---->          statutory
# liquid             <---->          liquidity
# ratio              <---->              ratio
# slr                <---->                slr
# secur              <---->           security
# central            <---->            central
# bank               <---->               bank
# also               <---->               also
# stipul             <---->          stipulate
# total              <---->              total
# slr                <---->                slr
# secur              <---->           security
# held               <---->               held
# htm                <---->                htm
# categori           <---->           category
# per                <---->                per
# cent               <---->               cent
# demand             <---->             demand
# time               <---->               time
# liabil             <---->          liability
# dtl                <---->                dtl
# last               <---->               last
# friday             <---->             friday
# second             <---->             second
# preced             <---->            precede
# fortnight          <---->          fortnight
# accord             <---->             accord
# analyst            <---->            analyst
# rbi                <---->                rbi
# move               <---->               move
# protect            <---->            protect
# balancesheet       <---->      balancesheets
# nationalis         <---->        nationalise
# bank               <---->               bank
# impact             <---->             impact
# fall               <---->               fall
# govern             <---->         government
# secur              <---->           security
# price              <---->              price
# nationalis         <---->        nationalise
# bank               <---->               bank
# heavi              <---->              heavy
# investor           <---->           investor
# govern             <---->         government
# secur              <---->           security
# invest             <---->         investment
# exceed             <---->             exceed
# minimum            <---->            minimum
# level              <---->              level
# per                <---->                per
# cent               <---->               cent
# deposit            <---->            deposit
# present            <---->          presently
# three              <---->              three
# categori           <---->           category
# bank               <---->               bank
# hold               <---->               hold
# secur              <---->           security
# includ             <---->            include
# htm                <---->                htm
# availableforsal    <---->   availableforsale
# heldfortrad        <---->     heldfortrading
# categori           <---->           category
# rbi                <---->                rbi
# regul              <---->         regulation
# stipul             <---->          stipulate
# bank               <---->               bank
# must               <---->               must
# mark               <---->               mark
# market             <---->             market
# hold               <---->            holding
# availableforsal    <---->   availableforsale
# heldfortrad        <---->     heldfortrading
# categori           <---->           category
# market             <---->             market
# circl              <---->             circle
# said               <---->                say
# bank               <---->               bank
# stock              <---->              stock
# pressur            <---->           pressure
# recent             <---->             recent
# past               <---->               past
# concern            <---->            concern
# impact             <---->             impact
# like               <---->             likely
# rise               <---->               rise
# interest           <---->           interest
# rate               <---->               rate
# wit                <---->            witness
# brisk              <---->              brisk
# buy                <---->             buying
# investor           <---->           investor
# chase              <---->              chase
# nationalis         <---->        nationalise
# bank               <---->               bank
# bse                <---->                bse
# state              <---->              state
# bank               <---->               bank
# india              <---->              india
# sbi                <---->                sbi
# activ              <---->           actively
# trade              <---->              trade
# counter            <---->            counter
# highest            <---->               high
# turnov             <---->           turnover
# rs                 <---->                  r
# crore              <---->              crore
# sbi                <---->                sbi
# scrip              <---->              scrip
# firm               <---->               firm
# rs                 <---->                  r
# rs                 <---->                  r
# bank               <---->               bank
# baroda             <---->             baroda
# also               <---->               also
# gain               <---->               gain
# rs                 <---->                  r
# finish             <---->             finish
# rs                 <---->                  r
# corpor             <---->        corporation
# bank               <---->               bank
# share              <---->              share
# rs                 <---->                  r
# end                <---->                end
# rs                 <---->                  r
# canara             <---->             canara
# bank               <---->               bank
# gain               <---->               gain
# rs                 <---->                  r
# finish             <---->             finish
# rs                 <---->                  r
# bse                <---->                bse
# bankex             <---->             bankex
# one                <---->                one
# lead               <---->               lead
# indic              <---->              index
# exchang            <---->           exchange
# gain               <---->               gain
# around             <---->             around
# point              <---->              point
# open               <---->            opening
# shot               <---->               shot
# day                <---->                day
# high               <---->               high
# close              <---->            closing
# rbi                <---->                rbi
# decis              <---->           decision
# rais               <---->              raise
# invest             <---->         investment
# limit              <---->              limit
# come               <---->               come
# time               <---->               time
# bank               <---->               bank
# wit                <---->            witness
# trade              <---->            trading
# gain               <---->               gain
# evapor             <---->          evaporate
# first              <---->              first
# quarter            <---->            quarter
# current            <---->            current
# fiscal             <---->             fiscal
# due                <---->                due
# sustain            <---->            sustain
# drop               <---->               drop
# price              <---->              price
# govern             <---->         government
# secur              <---->           security
# treasuri           <---->           treasury
# circl              <---->             circle
# feel               <---->               feel
# central            <---->            central
# bank               <---->               bank
# prepar             <---->            prepare
# bank               <---->            banking
# sector             <---->             sector
# interest           <---->           interest
# rate               <---->               rate
# hike               <---->               hike
# month              <---->              month
# come               <---->               come
# far                <---->                far
# rbi                <---->                rbi
# desist             <---->             desist
# rais               <---->              raise
# key                <---->                key
# rate               <---->               rate
# benchmark          <---->          benchmark
# bank               <---->               bank
# rate               <---->               rate
# still              <---->              still
# three              <---->              three
# decad              <---->             decade
# low                <---->                low
